# %% [markdown]
# # Multimodal Emotion Recognition v3 — DINOv2 + Temporal Attention + Gated Fusion
#
# **Changes over v2 (visual branch only — audio branch is identical):**
# - Visual backbone: `ConvNeXt V2 Base + SE` → **`DINOv2 ViT-B/14 + Temporal Self-Attention`**
# - Frame count: 8 → **16** (ViT benefits from richer temporal context; reduces per-frame overfitting)
# - Frame augmentation: independent per-frame → **consistent clip-level** (same random crop/flip/jitter applied to all T frames, preserving temporal coherence)
# - `FaceOnlyDataset` now returns full clips `(T, C, H, W)` so FER pre-training also trains the temporal path
# - `visual_dim` in GatedFusion: 1024 → **768** (DINOv2 ViT-B output dim)
# - Phase 1b unfreeze: last 2 ConvNeXt stages → **last 4 ViT transformer blocks**
#
# **Everything else is unchanged:** WavLM SER, audio preprocessing, RAVDESS dataset,
# speaker-stratified split, GatedFusion architecture, MultimodalEmotionModel,
# all training loops, evaluation, and gate analysis.
#
# **Pipeline:** RAVDESS video → MediaPipe face crops (16 frames) + torchaudio audio
# → Fine-tune SER (WavLM) → Fine-tune FER (DINOv2 + TemporalAttn) → Gated Fusion
#
# **Labels:** `angry · happy · neutral · sad`

# %%
# !pip uninstall mediapipe -y
# !pip install mediapipe==0.10.14
import mediapipe as mp
print(mp.__version__)
print(hasattr(mp,"solutions"))
# Out:
# Collecting mediapipe==0.10.14
#   Downloading mediapipe-0.10.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (25.12.19)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (0.7.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (0.7.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (2.0.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.12/dist-packages (from mediapipe==0.10.14) (4.13.0.92)
# Collecting protobuf<5,>=4.25.3 (from mediapipe==0.10.14)
#   Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.14)
#   Downloading sounddevice-0.5.5-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.14) (2.0.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe==0.10.14) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe==0.10.14) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe==0.10.14) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe==0.10.14) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.14) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->sounddevice>=0.4.4->mediapipe==0.10.14) (3.0)
# Downloading mediapipe-0.10.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 55.5 MB/s eta 0:00:00
# Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 17.6 MB/s eta 0:00:00
# Downloading sounddevice-0.5.5-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# a2a-sdk 0.3.25 requires protobuf>=5.29.5, but you have protobuf 4.25.9 which is incompatible.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# Successfully installed mediapipe-0.10.14 protobuf-4.25.9 sounddevice-0.5.5
# 2026-05-14 12:25:05.885410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778761506.515460      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778761506.636183      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778761507.753553      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778761507.753606      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778761507.753609      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778761507.753611      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 0.10.14
# True

# %%
# Cell 1 — Install dependencies
import sys
print(sys.executable)
# Uncomment if needed:
# !pip install timm>=0.9.16 transformers torchaudio mediapipe --quiet
# DINOv2 is loaded via timm — no extra install needed beyond timm>=0.9
# Out:
# /usr/bin/python3

# %%
# Cell 2 — Imports & Setup
import os, random, warnings, json
from pathlib import Path
from typing import Dict, Optional, List

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.cuda.amp import autocast, GradScaler

import torchaudio
import torchaudio.transforms as T
import timm
from transformers import WavLMModel, WavLMConfig
from torchvision import transforms
import torchvision.transforms.functional as TF   # NEW: needed for consistent clip augmentation
from PIL import Image
import cv2
import mediapipe as mp

from sklearn.metrics import (
    accuracy_score, f1_score, recall_score,
    confusion_matrix, classification_report
)
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm

warnings.filterwarnings("ignore")

def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.benchmark = True

seed_everything(42)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device : {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU    : {torch.cuda.get_device_name(0)}")
    print(f"Memory : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Device : cuda
# GPU    : Tesla T4
# Memory : 15.6 GB

# %%
# Cell 3 — Config & Paths
VIDEO_ROOT = "/kaggle/input/datasets/nausad01ali/ravdess"
SAVE_DIR   = "/kaggle/working/model_file"
os.makedirs(SAVE_DIR, exist_ok=True)

EMOTION_LABELS = ["angry", "happy", "neutral", "sad"]
NUM_CLASSES    = len(EMOTION_LABELS)
LABEL2IDX      = {e: i for i, e in enumerate(EMOTION_LABELS)}

RAVDESS_EMOTION_MAP = {
    "01": "neutral",   # neutral
    "02": "neutral",   # calm → treated as neutral
    "03": "happy",
    "04": "sad",
    "05": "angry",
    # 06=fear, 07=disgust, 08=surprise — skipped (not in our 4-class set)
}

# ── Audio config (UNCHANGED from v2) ──────────────────────────────────────────
SAMPLE_RATE  = 16_000
MAX_DURATION = 3.5
MAX_SAMPLES  = int(SAMPLE_RATE * MAX_DURATION)  # 56,000

# ── SER pre-training (UNCHANGED) ──────────────────────────────────────────────
SER_BATCH_SIZE   = 16
SER_EPOCHS       = 20
SER_LR           = 5e-5
SER_WEIGHT_DECAY = 1e-4

# ── FER pre-training ──────────────────────────────────────────────────────────
# DINOv2 ViT-B/14: lower LR than ConvNeXt (ViTs are sensitive to large LRs)
FER_BATCH_SIZE   = 8    # reduced: 16 frames × 224² × float32 is heavier
FER_EPOCHS       = 20
FER_LR           = 5e-5   # lower than v2 (1e-4) — ViT head warm-up
FER_WEIGHT_DECAY = 1e-4

# ── NEW: visual config ─────────────────────────────────────────────────────────
NUM_FRAMES  = 16       # was 8 — more temporal context for ViT
VISUAL_DIM  = 768      # DINOv2 ViT-B/14 CLS output dim (was 1024 for ConvNeXt)
IMG_SIZE    = 224      # 224 / patch_size_14 = 16 patches/side — clean division

# ── Fusion training (mostly UNCHANGED) ────────────────────────────────────────
BATCH_SIZE   = 4       # 4 samples × 16 frames × 224² — keep GPU memory safe
EPOCHS       = 30
FUSION_LR    = 1e-3
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.1
DROPOUT      = 0.3
PATIENCE     = 8
GRAD_CLIP    = 1.0
FUSION_DIM   = 512

# ── Phase 3 optional fine-tuning ──────────────────────────────────────────────
FINETUNE_BACKBONE_LR = 1e-6
FINETUNE_FUSION_LR   = 1e-4
FINETUNE_EPOCHS      = 10

print(f"Emotion labels : {EMOTION_LABELS}")
print(f"Num frames     : {NUM_FRAMES}  (↑ from 8)")
print(f"Visual dim     : {VISUAL_DIM}  (↓ from 1024, DINOv2 ViT-B output)")
print(f"Fusion dim     : {FUSION_DIM}")
print(f"Max audio len  : {MAX_DURATION}s = {MAX_SAMPLES} samples")
print(f"Save dir       : {SAVE_DIR}")
# Out:
# Emotion labels : ['angry', 'happy', 'neutral', 'sad']
# Num frames     : 16  (↑ from 8)
# Visual dim     : 768  (↓ from 1024, DINOv2 ViT-B output)
# Fusion dim     : 512
# Max audio len  : 3.5s = 56000 samples
# Save dir       : /kaggle/working/model_file

# %% [markdown]
# ## Audio Preprocessing (identical to v2 — no changes)

# %%
# Cell 4 — Audio Preprocessing  [UNCHANGED from v2]
def load_wav_from_file(path: str, sr: int = SAMPLE_RATE) -> np.ndarray:
    """Load and resample audio from any file (wav, mp4, etc)."""
    wav, orig_sr = torchaudio.load(path)
    if wav.shape[0] > 1:
        wav = wav.mean(dim=0, keepdim=True)
    if orig_sr != sr:
        wav = torchaudio.transforms.Resample(orig_sr, sr)(wav)
    return wav.squeeze().numpy().astype(np.float32)

def vad_trim(wav: np.ndarray, sr: int = SAMPLE_RATE,
             thr: float = 0.01, frame_ms: int = 20) -> np.ndarray:
    """Energy-based VAD: trim low-energy leading/trailing frames."""
    hop = int(sr * frame_ms / 1000)
    n   = max(1, (len(wav) - hop) // hop + 1)
    rms = np.array([np.sqrt(np.mean(wav[i*hop : i*hop+hop]**2)) for i in range(n)])
    if rms.max() <= 1e-8:
        return wav
    voiced = np.where(rms >= thr * rms.max())[0]
    return wav[voiced[0]*hop : min(len(wav), voiced[-1]*hop + hop)] if len(voiced) else wav

def normalize_amplitude(wav: np.ndarray, peak: float = 0.95) -> np.ndarray:
    mx = np.abs(wav).max()
    return wav * (peak / mx) if mx > 1e-6 else wav

def segment_and_pad(wav: np.ndarray, length: int = MAX_SAMPLES) -> np.ndarray:
    if len(wav) >= length:
        start = (len(wav) - length) // 2
        return wav[start : start + length]
    return np.pad(wav, (0, length - len(wav)))

def preprocess_audio(path: str) -> Optional[np.ndarray]:
    """Full audio pipeline: load → VAD trim → normalize → pad."""
    try:
        wav = load_wav_from_file(path)
        wav = vad_trim(wav)
        wav = normalize_amplitude(wav)
        return segment_and_pad(wav)
    except Exception:
        return None

def audio_augment(wav: np.ndarray) -> np.ndarray:
    if random.random() < 0.5:
        wav = wav * 10 ** (random.uniform(-6, 6) / 20)
    if random.random() < 0.3:
        wav = wav + 0.005 * np.random.randn(len(wav)).astype(np.float32)
    if random.random() < 0.3:
        shift = int(random.uniform(-0.1, 0.1) * len(wav))
        wav = np.roll(wav, shift)
    return normalize_amplitude(wav)

print("Audio preprocessing ready.")
# Out:
# Audio preprocessing ready.

# %% [markdown]
# ## Visual Preprocessing
#
# **Changes from v2:**
# - `NUM_FRAMES = 16` (was 8)
# - New `ConsistentVideoTransform` replaces per-frame independent transforms.
#   A single set of random parameters (crop box, flip coin, colour-jitter scalars)
#   is sampled **once per clip** and applied identically to every frame.
#   This is critical for temporal coherence — the temporal transformer must see
#   natural expression dynamics, not augmentation artifacts masquerading as motion.

# %%
# Cell 5 — Face Extraction  [NUM_FRAMES updated to 16; MediaPipe unchanged]
mp_face_detection = mp.solutions.face_detection

# ── NEW: Consistent clip-level augmentation ────────────────────────────────────
# Key design principle: sample random parameters ONCE per clip, apply to ALL frames.
# Without this, independent per-frame jitter creates artificial "flicker" that the
# temporal transformer interprets as motion signal — leading to noisy gradients.

class ConsistentVideoTransform:
    """
    Applies the same random augmentation to every frame in a video clip.

    Train mode:
      - RandomResizedCrop  (scale 0.7-1.0, aspect 0.85-1.15) — same window for all frames
      - RandomHorizontalFlip                                   — same coin for all frames
      - ColorJitter (brightness, contrast, saturation)        — same factors for all frames
    Eval mode:
      - Resize to (IMG_SIZE, IMG_SIZE) — deterministic

    Parameters are sampled once per __call__ invocation (i.e., once per clip).
    """
    _MEAN = [0.485, 0.456, 0.406]
    _STD  = [0.229, 0.224, 0.225]

    def __init__(self, size: int = IMG_SIZE, train: bool = True):
        self.size  = size
        self.train = train

    def __call__(self, frames: list) -> torch.Tensor:
        """
        Args:
            frames: list of PIL.Image  (length T)
        Returns:
            torch.Tensor of shape (T, 3, H, W), float32, normalised
        """
        if self.train:
            # ── sample augmentation params once ──────────────────────────────
            # ResizedCrop params
            i, j, h, w = transforms.RandomResizedCrop.get_params(
                frames[0], scale=(0.70, 1.00), ratio=(0.85, 1.15))
            # Horizontal flip
            do_flip = random.random() < 0.5
            # Colour jitter (mild — we're on face crops, not ImageNet scenes)
            brightness_factor  = random.uniform(0.80, 1.20)
            contrast_factor    = random.uniform(0.80, 1.20)
            saturation_factor  = random.uniform(0.85, 1.15)

            processed = []
            for f in frames:
                f = TF.resized_crop(f, i, j, h, w, (self.size, self.size),
                                    interpolation=TF.InterpolationMode.BICUBIC)
                if do_flip:
                    f = TF.hflip(f)
                f = TF.adjust_brightness(f, brightness_factor)
                f = TF.adjust_contrast(f, contrast_factor)
                f = TF.adjust_saturation(f, saturation_factor)
                t = TF.to_tensor(f)
                t = TF.normalize(t, self._MEAN, self._STD)
                processed.append(t)
        else:
            processed = []
            for f in frames:
                f = TF.resize(f, (self.size, self.size),
                              interpolation=TF.InterpolationMode.BICUBIC)
                t = TF.to_tensor(f)
                t = TF.normalize(t, self._MEAN, self._STD)
                processed.append(t)

        return torch.stack(processed)  # (T, 3, H, W)


# Instantiate both variants for convenience
video_tf_train = ConsistentVideoTransform(size=IMG_SIZE, train=True)
video_tf_eval  = ConsistentVideoTransform(size=IMG_SIZE, train=False)


# ── Face extraction (unchanged except NUM_FRAMES) ────────────────────────────
def extract_faces_from_video(video_path: str,
                              num_frames: int = NUM_FRAMES) -> Optional[list]:
    """
    Extract `num_frames` face crops from a video using MediaPipe.
    Frames are sampled uniformly from the 10%-90% portion of the video
    to avoid title/fade frames.
    Pads by repeating the last valid face if fewer than num_frames//2 detected.

    No data-leakage risk: operates on a single video in isolation.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        return None
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total < num_frames:
        cap.release()
        return None

    frame_positions = np.linspace(0.1, 0.9, num_frames)
    faces = []

    with mp_face_detection.FaceDetection(
            model_selection=0, min_detection_confidence=0.5) as fd:
        for pos in frame_positions:
            cap.set(cv2.CAP_PROP_POS_FRAMES,
                    min(int(total * pos), total - 1))
            ret, frame = cap.read()
            if not ret:
                continue

            image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results   = fd.process(image_rgb)

            if results.detections:
                bbox = results.detections[0].location_data.relative_bounding_box
                ih, iw, _ = frame.shape
                x  = int(bbox.xmin * iw)
                y  = int(bbox.ymin * ih)
                w  = int(bbox.width  * iw)
                h  = int(bbox.height * ih)
                x1, y1 = max(0, x - 20), max(0, y - 20)
                x2, y2 = min(iw, x + w + 20), min(ih, y + h + 20)
                faces.append(Image.fromarray(image_rgb).crop((x1, y1, x2, y2)))

    cap.release()

    # Need at least half the frames to be valid
    if len(faces) >= num_frames // 2:
        while len(faces) < num_frames:
            faces.append(faces[-1])   # pad by repeating last valid face
        return faces[:num_frames]
    return None


print(f"Face extraction ready  (num_frames={NUM_FRAMES}, img_size={IMG_SIZE}x{IMG_SIZE}).")
print("ConsistentVideoTransform defined  (train + eval variants).")
# Out:
# Face extraction ready  (num_frames=16, img_size=224x224).
# ConsistentVideoTransform defined  (train + eval variants).

# %%
# Quick sanity-check on first video
vf = sorted(Path(VIDEO_ROOT).rglob("*.mp4"))[0]
faces = extract_faces_from_video(str(vf))
print(f"Got {len(faces)} face crops" if faces else "FAILED — check VIDEO_ROOT")
if faces:
    clip_train = video_tf_train(faces)
    clip_eval  = video_tf_eval(faces)
    print(f"Train clip tensor : {clip_train.shape}  dtype={clip_train.dtype}")
    print(f"Eval  clip tensor : {clip_eval.shape}")
    # Verify all frames got the SAME crop by checking corner pixels match
    # (they will differ by colour-jitter only, not by spatial shift)
    print(f"Frame 0 spatial max: {clip_eval[0].max():.4f} | Frame 7: {clip_eval[7].max():.4f}")
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1778761580.152622      84 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Got 16 face crops
# Train clip tensor : torch.Size([16, 3, 224, 224])  dtype=torch.float32
# Eval  clip tensor : torch.Size([16, 3, 224, 224])
# Frame 0 spatial max: 2.6400 | Frame 7: 2.6400

# %% [markdown]
# ## Dataset Builder (unchanged from v2 — NUM_FRAMES change propagates through config)

# %%
# Cell 6 — Dataset Builder  [UNCHANGED logic; NUM_FRAMES now 16 via config]
def parse_filename(fname: str) -> Optional[Dict]:
    parts = Path(fname).stem.split("-")
    if len(parts) != 7:
        return None
    return {
        "modality"    : parts[0],
        "channel"     : parts[1],
        "emotion_code": parts[2],
        "intensity"   : parts[3],
        "statement"   : parts[4],
        "repetition"  : parts[5],
        "actor"       : parts[6],
    }


def build_dataset(video_root: str) -> pd.DataFrame:
    """
    Scan RAVDESS video directory.
    Audio is extracted directly from each video file (no cross-file path risk).
    Returns DataFrame with pre-cached audio arrays and lists of 16 face PIL images.

    Data-leakage note: preprocessing is per-sample and stateless (uses ImageNet
    normalisation constants, not dataset statistics). No global normalisation is
    computed here. The speaker-stratified split in Cell 7 ensures no actor appears
    in more than one partition.
    """
    records = []
    skipped = {"modality": 0, "channel": 0, "emotion": 0, "face": 0, "audio": 0}

    video_files = sorted(Path(video_root).rglob("*.mp4"))
    print(f"Found {len(video_files)} .mp4 files in {video_root}")

    for vf in tqdm(video_files, desc="Building dataset"):
        info = parse_filename(vf.name)
        if info is None:
            continue

        # Only full-AV speech (modality=01, channel=01)
        if info["modality"] != "01":
            skipped["modality"] += 1; continue
        if info["channel"] != "01":
            skipped["channel"] += 1; continue

        emotion = RAVDESS_EMOTION_MAP.get(info["emotion_code"])
        if emotion is None:
            skipped["emotion"] += 1; continue

        # Extract 16 face crops
        faces = extract_faces_from_video(str(vf))
        if faces is None:
            skipped["face"] += 1; continue

        # Extract audio directly from the video file
        audio = preprocess_audio(str(vf))
        if audio is None:
            skipped["audio"] += 1; continue

        records.append({
            "video_path" : str(vf),
            "actor"      : int(info["actor"]),
            "emotion"    : emotion,
            "label"      : LABEL2IDX[emotion],
            "audio_cache": audio,
            "face_cache" : faces,   # list of 16 PIL images
        })

    df = pd.DataFrame(records)
    print(f"\nPaired samples : {len(df)}")
    print(f"Skipped        : {skipped}")
    print(f"\nEmotion distribution:")
    print(df["emotion"].value_counts().to_string())
    return df


df_all = build_dataset(VIDEO_ROOT)
# Out:
# Found 2880 .mp4 files in /kaggle/input/datasets/nausad01ali/ravdess
# Building dataset:   0%|          | 0/2880 [00:00<?, ?it/s]
# W0000 00:00:1778761584.708089     101 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761587.725711     115 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761589.082586     125 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761590.572314     137 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761592.069306     147 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761593.620634     159 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761595.063624     170 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761596.555376     180 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761598.058292     192 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761599.570615     203 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761601.151245     213 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761602.661657     225 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761604.189692     236 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761605.661737     247 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761607.145280     258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761608.680721     269 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761610.168905     280 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761611.640828     291 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761613.075171     302 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761614.525952     313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761615.959447     324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761617.472385     335 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761619.061018     346 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761620.584875     357 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761622.109885     368 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761623.637865     379 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761625.110128     390 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761626.610072     401 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761628.094855     412 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761629.591102     422 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761631.063009     434 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761632.576302     445 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761634.081359     456 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761635.485486     467 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761636.872347     478 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761638.335657     488 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761639.910732     500 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761640.784804     511 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761641.647077     522 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761642.538773     532 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761643.366644     544 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761644.228253     555 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761645.068538     565 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761645.906417     577 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761646.735894     588 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761647.566251     599 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761648.465514     610 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761649.313057     621 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761650.147970     632 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761651.007583     643 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761651.966425     654 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761652.891299     664 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761653.847675     676 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761654.748604     687 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761655.635870     698 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761656.535851     709 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761657.439037     720 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761658.320749     731 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761659.211647     742 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761660.084797     753 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761661.045493     764 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761661.933518     775 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761662.848266     786 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761663.737267     797 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761664.599344     808 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761665.456486     819 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761666.327795     830 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761667.229670     841 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761668.149607     852 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761668.999008     863 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761669.865505     874 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761670.746771     885 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761671.702883     895 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761672.777658     907 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761673.816410     917 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761674.829750     929 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761675.878395     940 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761676.957373     951 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761678.031780     962 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761679.068325     973 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761680.111941     984 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761681.240395     994 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761682.323395    1006 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761683.343916    1017 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761684.403469    1027 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761685.445097    1039 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761686.368985    1050 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761687.371315    1061 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761688.382646    1073 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761689.404080    1083 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761690.413281    1094 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761691.445564    1105 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761692.448275    1116 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761693.464228    1127 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761694.579299    1138 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761695.676255    1149 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761696.743810    1160 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761697.792156    1171 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761698.826331    1182 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761699.839541    1193 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761700.811371    1204 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761701.881488    1215 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761702.930268    1226 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761704.008099    1237 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761705.024531    1248 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761706.063296    1259 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761707.081880    1270 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761708.104261    1281 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761709.158836    1292 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761710.045190    1303 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761710.921072    1313 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761711.801349    1325 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761712.651164    1336 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761713.592003    1346 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761714.492412    1358 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761715.357342    1369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761716.288490    1380 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761717.195571    1391 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761718.140893    1402 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761719.098896    1413 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761720.053730    1424 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761721.019480    1435 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761721.982657    1446 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761722.952262    1457 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761723.886388    1468 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761724.851832    1479 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761725.821558    1490 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761726.734108    1501 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761727.706648    1512 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761728.648101    1523 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761729.571612    1534 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761730.509815    1545 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761731.526379    1556 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761732.456849    1567 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761733.434602    1577 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761734.393110    1589 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761735.351153    1600 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761736.278859    1611 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761737.197801    1621 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761738.158524    1633 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761739.126194    1644 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761740.072202    1655 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761741.063073    1666 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761742.019373    1677 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761742.968534    1688 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761743.842126    1699 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761744.771714    1710 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761745.660918    1721 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761746.557443    1732 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761747.506286    1743 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761748.662707    1754 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761749.559359    1765 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761750.471144    1775 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761751.455624    1786 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761752.438667    1798 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761753.535928    1809 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761754.414505    1819 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761755.328035    1831 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761756.183094    1842 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761757.082433    1853 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761757.979968    1863 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761758.899837    1874 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761759.811309    1886 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761760.731071    1897 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761761.654031    1908 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761762.527273    1919 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761763.388889    1930 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761764.276487    1940 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761765.175615    1951 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761766.099800    1963 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761766.996838    1974 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761767.937720    1985 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761768.827312    1996 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761769.775781    2007 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761770.719453    2018 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761771.684241    2029 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761772.620065    2040 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761773.499696    2051 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761774.444690    2062 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761775.305028    2073 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761776.184034    2084 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761777.711546    2095 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761779.232113    2106 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761780.770552    2117 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761782.364516    2128 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761783.999850    2139 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761785.546403    2150 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761787.095377    2161 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761788.671168    2172 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761790.249121    2183 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761791.955434    2194 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761793.494384    2205 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761795.082507    2216 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761796.630151    2227 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761798.063536    2237 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761799.536364    2249 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761801.071944    2260 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761802.622072    2272 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761804.117609    2281 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761805.659793    2293 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761807.104373    2304 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761808.741678    2315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761810.233491    2325 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761811.806179    2337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761813.350497    2347 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761814.915276    2358 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761816.384482    2369 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761817.987993    2381 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761819.582167    2392 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761821.229773    2402 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761822.775729    2414 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761824.386493    2425 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761825.952015    2436 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761827.494931    2447 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761829.091050    2458 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761830.693283    2469 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761832.300580    2480 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761833.315220    2491 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761834.391875    2502 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761835.433830    2513 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761836.486428    2524 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761837.531578    2535 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761838.563338    2546 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761839.637529    2557 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761840.735269    2568 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761841.826810    2579 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761842.895583    2590 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761843.940630    2600 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761844.953323    2612 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761846.013854    2623 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761847.066743    2634 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761848.078113    2645 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761849.069337    2656 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761850.087627    2667 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761851.165627    2678 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761852.249884    2689 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761853.279712    2700 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761854.346422    2711 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761855.326863    2722 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761856.389525    2733 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761857.441499    2744 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761858.487861    2755 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761859.540192    2766 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761860.508893    2777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761861.554825    2788 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761862.611487    2799 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761863.623442    2810 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761864.676755    2821 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761865.748857    2832 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761866.744906    2843 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761867.784642    2853 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761868.765498    2865 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761869.741437    2876 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761870.738971    2887 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761871.742358    2898 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761872.793861    2909 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761873.875483    2919 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761874.825308    2931 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761875.816655    2942 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761876.808130    2953 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761877.773303    2964 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761878.784453    2974 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778761879.818316    2986 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
# W0000 00:00:1778762486.286642    8662 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762487.149789    8673 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762488.003836    8684 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762488.880572    8695 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762489.739467    8706 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762490.649234    8717 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762491.540737    8728 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762492.413336    8739 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762493.320121    8750 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762494.208804    8761 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762495.114672    8772 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762495.986861    8783 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762496.839798    8794 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762497.715593    8805 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762498.599433    8816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762499.645068    8827 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762500.688025    8838 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762501.711316    8849 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762502.755853    8861 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762503.758408    8871 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762504.750607    8882 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762505.733656    8893 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762506.742329    8904 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762507.798015    8915 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762508.864682    8926 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762509.849215    8937 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762510.966238    8948 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762511.954038    8959 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762512.950655    8970 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762513.907679    8980 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762514.852007    8993 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762515.796683    9003 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762516.732794    9014 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762517.683270    9025 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762518.647811    9036 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762519.586039    9047 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762520.582142    9058 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762521.680598    9069 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762522.671789    9080 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762523.688077    9091 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762524.657370    9102 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762525.662381    9113 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762526.715188    9123 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762527.668452    9135 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762528.657803    9146 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762529.607554    9157 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762530.567017    9168 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762531.526113    9179 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762532.463644    9190 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762533.428196    9201 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762534.411894    9212 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762535.259874    9223 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762536.096597    9234 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762536.929274    9246 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762537.751937    9256 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762538.621519    9267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762539.449040    9278 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762540.287897    9289 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762541.158309    9299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762541.979065    9311 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762542.802746    9322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762543.666742    9333 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762544.494926    9343 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762545.310153    9355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762546.138497    9366 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762546.988460    9377 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762547.834658    9387 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762548.699049    9398 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762549.581597    9409 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762550.451800    9421 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762551.337945    9432 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762552.180423    9443 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762553.029891    9454 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762553.871353    9465 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762554.747400    9476 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762555.592993    9487 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762556.530020    9498 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762557.371874    9509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762558.255169    9520 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762559.077682    9531 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762559.916310    9542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762560.760271    9553 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762561.635327    9564 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762562.484877    9575 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762563.312747    9586 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778762564.148682    9597 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Paired samples : 864
# Skipped        : {'modality': 1440, 'channel': 0, 'emotion': 576, 'face': 0, 'audio': 0}
#
# Emotion distribution:
# emotion
# neutral    288
# happy      192
# sad        192
# angry      192

# %%
# Cell 7 — Speaker-Stratified Split  [UNCHANGED from v2 — no data leakage]
#
# Data-leakage note: split is performed at the ACTOR level, not sample level.
# Every clip from a given actor lands in exactly one partition.
# This prevents the model from memorising actor-specific speech patterns /
# facial geometry and reporting inflated test metrics.

def speaker_stratified_split(df: pd.DataFrame,
                              train_frac=0.7, val_frac=0.1, seed=42):
    rng    = np.random.default_rng(seed)
    actors = df["actor"].unique().copy()
    rng.shuffle(actors)

    n_tr = max(1, int(len(actors) * train_frac))
    n_va = max(1, int(len(actors) * val_frac))

    train_actors = set(actors[:n_tr])
    val_actors   = set(actors[n_tr : n_tr + n_va])
    test_actors  = set(actors[n_tr + n_va:])

    tr = df[df["actor"].isin(train_actors)].reset_index(drop=True)
    va = df[df["actor"].isin(val_actors)].reset_index(drop=True)
    te = df[df["actor"].isin(test_actors)].reset_index(drop=True)

    print(f"Split by speakers — Train: {len(tr)} | Val: {len(va)} | Test: {len(te)}")
    print(f"  Train actors : {sorted(train_actors)}")
    print(f"  Val   actors : {sorted(val_actors)}")
    print(f"  Test  actors : {sorted(test_actors)}")

    # Leakage sanity-check: no actor should appear in more than one split
    assert not (train_actors & val_actors), "LEAKAGE: actor overlap train/val"
    assert not (train_actors & test_actors), "LEAKAGE: actor overlap train/test"
    assert not (val_actors   & test_actors), "LEAKAGE: actor overlap val/test"
    print("  ✓ No actor overlap across splits.")
    return tr, va, te


train_df, val_df, test_df = speaker_stratified_split(df_all)
# Out:
# Split by speakers — Train: 576 | Val: 72 | Test: 216
#   Train actors : [np.int64(1), np.int64(4), np.int64(6), np.int64(7), np.int64(8), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(24)]
#   Val   actors : [np.int64(15), np.int64(23)]
#   Test  actors : [np.int64(2), np.int64(3), np.int64(5), np.int64(9), np.int64(14), np.int64(22)]
#   ✓ No actor overlap across splits.

# %% [markdown]
# ## Dataset Classes
#
# **Key change vs v2:**
# `FaceOnlyDataset` now returns **full clips `(T, C, H, W)`** using `ConsistentVideoTransform`,
# not a single randomly-selected frame. This is necessary because the new `FERModel`
# has a temporal self-attention module that must be trained end-to-end on clip inputs —
# training on single frames would leave the temporal path completely untrained.
#
# `MultimodalDataset` similarly uses `ConsistentVideoTransform` instead of stacking
# independently transformed frames.
#
# `AudioOnlyDataset` is **unchanged**.

# %%
# Cell 8 — Dataset Classes  [FaceOnlyDataset and MultimodalDataset updated]

class AudioOnlyDataset(Dataset):
    """For SER pre-training phase.  [UNCHANGED from v2]"""
    def __init__(self, df: pd.DataFrame, augment: bool = False):
        self.df      = df.reset_index(drop=True)
        self.augment = augment

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        wav = row["audio_cache"].copy()
        if self.augment:
            wav = audio_augment(wav)
        return torch.from_numpy(segment_and_pad(wav)), int(row["label"])


class FaceOnlyDataset(Dataset):
    """
    For FER pre-training phase.

    v2: returned a single frame (C, H, W)
    v3: returns the full clip (T, C, H, W) so the temporal self-attention
        path is trained end-to-end during Phase 1.

    ConsistentVideoTransform is used to ensure temporal coherence:
    the same random crop/flip/colour params are applied to all T frames.
    """
    def __init__(self, df: pd.DataFrame, video_tf=None, augment: bool = False):
        self.df       = df.reset_index(drop=True)
        self.video_tf = video_tf if video_tf is not None else video_tf_eval
        self.augment  = augment

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row   = self.df.iloc[idx]
        faces = row["face_cache"]          # list of T=16 PIL images
        clip  = self.video_tf(faces)       # (T, 3, H, W)
        return clip, int(row["label"])


class MultimodalDataset(Dataset):
    """
    For fusion training phase.

    Audio path: unchanged.
    Visual path: ConsistentVideoTransform → (T, 3, H, W) clip tensor.
    """
    def __init__(self, df: pd.DataFrame, video_tf=None, augment: bool = False):
        self.df       = df.reset_index(drop=True)
        self.video_tf = video_tf if video_tf is not None else video_tf_eval
        self.augment  = augment

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row   = self.df.iloc[idx]
        wav   = row["audio_cache"].copy()
        if self.augment:
            wav = audio_augment(wav)
        faces = row["face_cache"]          # list of T=16 PIL images
        clip  = self.video_tf(faces)       # (T, 3, H, W)
        return torch.from_numpy(segment_and_pad(wav)), clip, int(row["label"])


def make_loaders(train, val, test, dataset_class, kwargs_train, kwargs_eval,
                 batch_size=16, num_workers=0):
    tr = DataLoader(dataset_class(train, **kwargs_train),
                    batch_size=batch_size, shuffle=True,
                    num_workers=num_workers, pin_memory=True, drop_last=True)
    va = DataLoader(dataset_class(val,  **kwargs_eval),
                    batch_size=batch_size, num_workers=num_workers, pin_memory=True)
    te = DataLoader(dataset_class(test, **kwargs_eval),
                    batch_size=batch_size, num_workers=num_workers, pin_memory=True)
    return tr, va, te


print("Dataset classes defined.")
# Out:
# Dataset classes defined.

# %%
# Dataset sanity-check
ds_mm = MultimodalDataset(train_df, video_tf=video_tf_train, augment=True)
wav_s, clip_s, lbl_s = ds_mm[0]
print(f"wav  : {wav_s.shape}         — expected (56000,)")
print(f"clip : {clip_s.shape}  — expected ({NUM_FRAMES}, 3, {IMG_SIZE}, {IMG_SIZE})")
print(f"label: {lbl_s}  ({EMOTION_LABELS[lbl_s]})")

ds_fer = FaceOnlyDataset(train_df, video_tf=video_tf_train, augment=True)
clip_fer, lbl_fer = ds_fer[0]
print(f"FER clip : {clip_fer.shape}")
# Out:
# wav  : torch.Size([56000])         — expected (56000,)
# clip : torch.Size([16, 3, 224, 224])  — expected (16, 3, 224, 224)
# label: 2  (neutral)
# FER clip : torch.Size([16, 3, 224, 224])

# %% [markdown]
# ## Phase 0 — SER Pre-Training (audio-only)  [IDENTICAL to v2]

# %%
# Cell 9 — SER Model Architecture  [UNCHANGED from v2]

# !pip install torchinfo


class SpeakerNorm(nn.Module):
    def __init__(self, dim: int = 768, eps: float = 1e-6):
        super().__init__()
        self.norm = nn.InstanceNorm1d(dim, eps=eps, affine=True)
    def forward(self, x):
        return self.norm(x.transpose(1, 2)).transpose(1, 2)


class WeightedLayerFusion(nn.Module):
    def __init__(self, k: int = 12):
        super().__init__()
        self.k      = k
        self.weight = nn.Parameter(torch.zeros(k))
    def forward(self, hidden_states):
        chosen  = hidden_states[-self.k:]
        w       = torch.softmax(self.weight, dim=0)
        stacked = torch.stack(chosen, dim=0)
        return (stacked * w[:, None, None, None]).sum(0)


class AttentionPooling(nn.Module):
    def __init__(self, hidden_size: int = 768, n_heads: int = 4):
        super().__init__()
        self.attn  = nn.MultiheadAttention(hidden_size, n_heads,
                                            batch_first=True, dropout=0.1)
        self.query = nn.Parameter(torch.randn(1, 1, hidden_size) * 0.02)
    def forward(self, x):
        q = self.query.expand(x.size(0), -1, -1)
        out, _ = self.attn(q, x, x)
        return out.squeeze(1)


class SERModel(nn.Module):
    """
    Speech Emotion Recognition model.
    WavLM-Base+ → Weighted layer fusion → SpeakerNorm → AttentionPool → Classifier
    [UNCHANGED from v2]
    """
    def __init__(self, n_class: int = 4,
                 backbone_name: str = "microsoft/wavlm-base-plus"):
        super().__init__()
        cfg = WavLMConfig.from_pretrained(backbone_name, output_hidden_states=True)
        self.backbone   = WavLMModel.from_pretrained(backbone_name, config=cfg,
                                                      use_safetensors=True)
        self.fuse       = WeightedLayerFusion(k=12)
        self.spk_norm   = SpeakerNorm(dim=768)
        self.attn_pool  = AttentionPooling(768, 4)
        self.layer_norm = nn.LayerNorm(768)
        self.emotion_head = nn.Sequential(
            nn.Linear(768, 256), nn.LayerNorm(256), nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(256, n_class),
        )
        for p in self.backbone.parameters():
            p.requires_grad = False

    def _embed(self, wav: torch.Tensor) -> torch.Tensor:
        out = self.backbone(wav, output_hidden_states=True)
        h   = self.fuse(out.hidden_states)
        h   = self.spk_norm(h)
        z   = self.attn_pool(h)
        return self.layer_norm(z)

    def forward(self, wav: torch.Tensor) -> torch.Tensor:
        return self.emotion_head(self._embed(wav))

    def extract_features(self, wav: torch.Tensor) -> torch.Tensor:
        return self._embed(wav)


ser_model = SERModel(n_class=NUM_CLASSES).to(DEVICE)
trainable = sum(p.numel() for p in ser_model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in ser_model.parameters())
print(f"SER model — trainable: {trainable:,} / total: {total:,}")

from torchinfo import summary

summmary_ser = summary(
    ser_model,
    input_size=(1, 16000),   # batch_size, audio_samples
    device=DEVICE
)
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/248 [00:00<?, ?it/s]
# SER model — trainable: 2,564,624 / total: 96,946,560

# %%
summmary_ser

summary_str = str(summmary_ser)

# Print in notebook
print(summary_str)

# ===== Save summary as TXT =====
with open("SER_Phase10_Model_Summary.txt", "w") as f:
    f.write(summary_str)

# ===== Save summary as PNG =====
plt.figure(figsize=(24, 30))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=8,
    va='top'
)

plt.axis('off')

plt.savefig(
    "SER_Phase10_Model_Summary.png",
    dpi=1200,
    bbox_inches='tight'
)

plt.close()

print("\nSER Phase 10 model summary saved successfully.")
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# SERModel                                                [1, 4]                    --
# ├─WavLMModel: 1-1                                       [1, 49, 768]              768
# │    └─WavLMFeatureEncoder: 2-1                         [1, 512, 49]              --
# │    │    └─ModuleList: 3-1                             --                        (4,200,448)
# │    └─WavLMFeatureProjection: 2-2                      [1, 49, 768]              --
# │    │    └─LayerNorm: 3-2                              [1, 49, 512]              (1,024)
# │    │    └─Linear: 3-3                                 [1, 49, 768]              (393,984)
# │    │    └─Dropout: 3-4                                [1, 49, 768]              --
# │    └─WavLMEncoder: 2-3                                [1, 49, 768]              --
# │    │    └─WavLMPositionalConvEmbedding: 3-5           [1, 49, 768]              (4,719,488)
# │    │    └─LayerNorm: 3-6                              [1, 49, 768]              (1,536)
# │    │    └─Dropout: 3-7                                [1, 49, 768]              --
# │    │    └─ModuleList: 3-8                             --                        (85,064,688)
# ├─WeightedLayerFusion: 1-2                              [1, 49, 768]              12
# ├─SpeakerNorm: 1-3                                      [1, 49, 768]              --
# │    └─InstanceNorm1d: 2-4                              [1, 768, 49]              1,536
# ├─AttentionPooling: 1-4                                 [1, 768]                  768
# │    └─MultiheadAttention: 2-5                          [1, 1, 768]               2,362,368
# ├─LayerNorm: 1-5                                        [1, 768]                  1,536
# ├─Sequential: 1-6                                       [1, 4]                    --
# │    └─Linear: 2-6                                      [1, 256]                  196,864
# │    └─LayerNorm: 2-7                                   [1, 256]                  512
# │    └─GELU: 2-8                                        [1, 256]                  --
# │    └─Dropout: 2-9                                     [1, 256]                  --
# │    └─Linear: 2-10                                     [1, 4]                    1,028
# =========================================================================================================
# Total params: 96,946,560
# Trainable params: 2,564,624
# Non-trainable params: 94,381,936
# Total mult-adds (Units.GIGABYTES): 2.51
# =========================================================================================================
# Input size (MB): 0.06
# Forward/backward pass size (MB): 66.47
# Params size (MB): 246.06
# Estimated Total Size (MB): 312.59
# =========================================================================================================
#
# SER Phase 10 model summary saved successfully.

# %%
# Cell 10 — SER Phase 0a: Train head only  [UNCHANGED from v2]

ser_train_loader, ser_val_loader, ser_test_loader = make_loaders(
    train_df, val_df, test_df,
    AudioOnlyDataset,
    kwargs_train={"augment": True},
    kwargs_eval ={"augment": False},
    batch_size=SER_BATCH_SIZE
)

def train_epoch_1d(model, loader, optimizer, criterion, scaler):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for wav, labels in tqdm(loader, desc="SER train", leave=False):
        wav, labels = wav.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        with autocast():
            logits = model(wav)
            loss   = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_([p for p in model.parameters() if p.requires_grad], GRAD_CLIP)
        scaler.step(optimizer); scaler.update()
        total_loss += loss.item() * labels.size(0)
        correct    += (logits.argmax(1) == labels).sum().item()
        total      += labels.size(0)
    return total_loss / total, correct / total

@torch.no_grad()
def eval_1d(model, loader, criterion):
    model.eval()
    total_loss, all_preds, all_labels = 0, [], []
    for wav, labels in tqdm(loader, desc="SER eval", leave=False):
        wav, labels = wav.to(DEVICE), labels.to(DEVICE)
        with autocast():
            logits = model(wav)
            loss   = criterion(logits, labels)
        total_loss += loss.item() * labels.size(0)
        all_preds.extend(logits.argmax(1).cpu().tolist())
        all_labels.extend(labels.cpu().tolist())
    p, l = np.array(all_preds), np.array(all_labels)
    return {
        "loss": total_loss / len(l),
        "acc" : accuracy_score(l, p),
        "uar" : recall_score(l, p, average="macro"),
        "f1"  : f1_score(l, p, average="macro"),
    }

criterion_ser = nn.CrossEntropyLoss(label_smoothing=0.1)
opt_ser       = AdamW([p for p in ser_model.parameters() if p.requires_grad],
                       lr=SER_LR, weight_decay=SER_WEIGHT_DECAY)
sch_ser       = CosineAnnealingWarmRestarts(opt_ser, T_0=10, T_mult=1, eta_min=1e-6)
scaler_ser    = GradScaler()
SER_CKPT      = os.path.join(SAVE_DIR, "ser_pretrained.pt")

best_uar, patience_ctr = 0.0, 0
print("SER Phase 0a — training head (backbone frozen)")
for epoch in range(1, SER_EPOCHS + 1):
    tr_loss, tr_acc = train_epoch_1d(ser_model, ser_train_loader, opt_ser, criterion_ser, scaler_ser)
    val_m           = eval_1d(ser_model, ser_val_loader, criterion_ser)
    sch_ser.step()
    print(f"Ep {epoch:02d}/{SER_EPOCHS}  train_acc={tr_acc:.4f} | val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}")
    if val_m["uar"] > best_uar:
        best_uar, patience_ctr = val_m["uar"], 0
        torch.save(ser_model.state_dict(), SER_CKPT)
        print(f"  ✓ Best UAR={best_uar:.4f} saved.")
    else:
        patience_ctr += 1
        if patience_ctr >= PATIENCE: print("Early stop (SER 0a)."); break

print(f"Phase 0a done. Best UAR={best_uar:.4f}")
# Out:
# SER Phase 0a — training head (backbone frozen)
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 01/20  train_acc=0.2726 | val_acc=0.4444  val_uar=0.4062
#   ✓ Best UAR=0.4062 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 02/20  train_acc=0.2934 | val_acc=0.4028  val_uar=0.3281
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 03/20  train_acc=0.3698 | val_acc=0.3611  val_uar=0.2812
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 04/20  train_acc=0.4358 | val_acc=0.4722  val_uar=0.4062
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 05/20  train_acc=0.5087 | val_acc=0.4861  val_uar=0.4219
#   ✓ Best UAR=0.4219 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 06/20  train_acc=0.5677 | val_acc=0.6389  val_uar=0.5938
#   ✓ Best UAR=0.5938 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 07/20  train_acc=0.6076 | val_acc=0.6389  val_uar=0.5938
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 08/20  train_acc=0.6285 | val_acc=0.5278  val_uar=0.4688
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 09/20  train_acc=0.6632 | val_acc=0.6528  val_uar=0.6094
#   ✓ Best UAR=0.6094 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 10/20  train_acc=0.6615 | val_acc=0.6111  val_uar=0.5625
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 11/20  train_acc=0.6597 | val_acc=0.6389  val_uar=0.5938
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 12/20  train_acc=0.7205 | val_acc=0.7361  val_uar=0.7031
#   ✓ Best UAR=0.7031 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 13/20  train_acc=0.7674 | val_acc=0.7500  val_uar=0.7188
#   ✓ Best UAR=0.7188 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 14/20  train_acc=0.7569 | val_acc=0.9028  val_uar=0.8906
#   ✓ Best UAR=0.8906 saved.
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 15/20  train_acc=0.7847 | val_acc=0.7778  val_uar=0.7500
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 16/20  train_acc=0.8160 | val_acc=0.8611  val_uar=0.8438
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 17/20  train_acc=0.8368 | val_acc=0.8194  val_uar=0.7969
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 18/20  train_acc=0.8368 | val_acc=0.8333  val_uar=0.8177
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 19/20  train_acc=0.8715 | val_acc=0.8611  val_uar=0.8490
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# Ep 20/20  train_acc=0.8646 | val_acc=0.8611  val_uar=0.8438
# Phase 0a done. Best UAR=0.8906

# %%
# summary_ser1 = summary(
#     ser_model,
#     input_size=(1, 16000),   # batch_size, audio_samples
#     device=DEVICE
# )

# summary_str = str(summary_ser1)

# # Print in notebook
# print(summary_str)

# # ===== Save summary as TXT =====
# with open("SER_Phase1a1_Model_Summary.txt", "w") as f:
#     f.write(summary_str)

# # ===== Save summary as PNG =====
# plt.figure(figsize=(24, 30))

# plt.text(
#     0.01,
#     0.99,
#     summary_str,
#     family='monospace',
#     fontsize=8,
#     va='top'
# )

# plt.axis('off')

# plt.savefig(
#     "SER_Phase1a1_Model_Summary.png",
#     dpi=1200,
#     bbox_inches='tight'
# )

# plt.close()

# print("\nSER Phase 1a1 model summary saved successfully.")

# %%
# summary_ser1

# %%
# Cell 11 — SER Phase 0b: Unfreeze top WavLM layers  [UNCHANGED from v2]

ser_model.load_state_dict(torch.load(SER_CKPT, map_location=DEVICE))

for layer in list(ser_model.backbone.encoder.layers)[-4:]:
    for p in layer.parameters():
        p.requires_grad = True

unf = sum(p.numel() for p in ser_model.parameters() if p.requires_grad)
print(f"SER Phase 0b — trainable after unfreeze: {unf:,}")

opt_ser2 = AdamW([
    {"params": [p for n, p in ser_model.named_parameters()
                if p.requires_grad and "backbone" in n], "lr": 1e-5},
    {"params": [p for n, p in ser_model.named_parameters()
                if p.requires_grad and "backbone" not in n], "lr": 2e-4},
], weight_decay=SER_WEIGHT_DECAY)

sch_ser2    = CosineAnnealingWarmRestarts(opt_ser2, T_0=5, eta_min=1e-7)
scaler_ser2 = GradScaler()
SER_CKPT_FT = os.path.join(SAVE_DIR, "ser_finetuned.pt")

best_uar2, patience_ctr2 = best_uar, 0
for epoch in range(1, 11):
    tr_loss, tr_acc = train_epoch_1d(ser_model, ser_train_loader, opt_ser2, criterion_ser, scaler_ser2)
    val_m           = eval_1d(ser_model, ser_val_loader, criterion_ser)
    sch_ser2.step()
    print(f"0b Ep {epoch:02d}/10  train_acc={tr_acc:.4f} | val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}")
    if val_m["uar"] > best_uar2:
        best_uar2, patience_ctr2 = val_m["uar"], 0
        torch.save(ser_model.state_dict(), SER_CKPT_FT)
        print(f"  ✓ Best UAR={best_uar2:.4f}")
    else:
        patience_ctr2 += 1
        if patience_ctr2 >= 5: print("Early stop (SER 0b)."); break

best_ser_ckpt = SER_CKPT_FT if os.path.exists(SER_CKPT_FT) else SER_CKPT
ser_model.load_state_dict(torch.load(best_ser_ckpt, map_location=DEVICE))
ser_model.eval()
for p in ser_model.parameters(): p.requires_grad = False

test_ser = eval_1d(ser_model, ser_test_loader, criterion_ser)
print(f"\nSER Test — Acc={test_ser['acc']:.4f}  UAR={test_ser['uar']:.4f}  F1={test_ser['f1']:.4f}")
print("SER backbone frozen for fusion stage.")
# Out:
# SER Phase 0b — trainable after unfreeze: 30,918,240
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 01/10  train_acc=0.7118 | val_acc=0.8333  val_uar=0.8281
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 02/10  train_acc=0.7830 | val_acc=0.7639  val_uar=0.7708
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 03/10  train_acc=0.8420 | val_acc=0.8194  val_uar=0.8229
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 04/10  train_acc=0.8906 | val_acc=0.8750  val_uar=0.8750
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 05/10  train_acc=0.9184 | val_acc=0.9167  val_uar=0.9167
#   ✓ Best UAR=0.9167
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 06/10  train_acc=0.8559 | val_acc=0.8472  val_uar=0.8333
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 07/10  train_acc=0.8698 | val_acc=0.7639  val_uar=0.7448
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 08/10  train_acc=0.9115 | val_acc=0.6667  val_uar=0.6927
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 09/10  train_acc=0.9253 | val_acc=0.9028  val_uar=0.9062
# SER train:   0%|          | 0/36 [00:00<?, ?it/s]
# SER eval:   0%|          | 0/5 [00:00<?, ?it/s]
# 0b Ep 10/10  train_acc=0.9635 | val_acc=0.8889  val_uar=0.8906
# Early stop (SER 0b).
# SER eval:   0%|          | 0/14 [00:00<?, ?it/s]
# SER Test — Acc=0.7593  UAR=0.7587  F1=0.7543
# SER backbone frozen for fusion stage.

# %%
summary_ser2 = summary(
    ser_model,
    input_size=(1, 16000),   # batch_size, audio_samples
    device=DEVICE
)

summary_str = str(summary_ser2)

# Print in notebook
print(summary_str)

# ===== Save summary as TXT =====
with open("SER_unfreeze_top_layer_WavLM.txt", "w") as f:
    f.write(summary_str)

# ===== Save summary as PNG =====
plt.figure(figsize=(24, 30))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=8,
    va='top'
)

plt.axis('off')

plt.savefig(
    "SER_unfreeze_top_layer_WavLM.png",
    dpi=1200,
    bbox_inches='tight'
)

plt.close()

print("\nSER Phase 1a model summary saved successfully.")
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# SERModel                                                [1, 4]                    --
# ├─WavLMModel: 1-1                                       [1, 49, 768]              768
# │    └─WavLMFeatureEncoder: 2-1                         [1, 512, 49]              --
# │    │    └─ModuleList: 3-1                             --                        (4,200,448)
# │    └─WavLMFeatureProjection: 2-2                      [1, 49, 768]              --
# │    │    └─LayerNorm: 3-2                              [1, 49, 512]              (1,024)
# │    │    └─Linear: 3-3                                 [1, 49, 768]              (393,984)
# │    │    └─Dropout: 3-4                                [1, 49, 768]              --
# │    └─WavLMEncoder: 2-3                                [1, 49, 768]              --
# │    │    └─WavLMPositionalConvEmbedding: 3-5           [1, 49, 768]              (4,719,488)
# │    │    └─LayerNorm: 3-6                              [1, 49, 768]              (1,536)
# │    │    └─Dropout: 3-7                                [1, 49, 768]              --
# │    │    └─ModuleList: 3-8                             --                        (85,064,688)
# ├─WeightedLayerFusion: 1-2                              [1, 49, 768]              (12)
# ├─SpeakerNorm: 1-3                                      [1, 49, 768]              --
# │    └─InstanceNorm1d: 2-4                              [1, 768, 49]              (1,536)
# ├─AttentionPooling: 1-4                                 [1, 768]                  768
# │    └─MultiheadAttention: 2-5                          [1, 1, 768]               2,362,368
# ├─LayerNorm: 1-5                                        [1, 768]                  (1,536)
# ├─Sequential: 1-6                                       [1, 4]                    --
# │    └─Linear: 2-6                                      [1, 256]                  (196,864)
# │    └─LayerNorm: 2-7                                   [1, 256]                  (512)
# │    └─GELU: 2-8                                        [1, 256]                  --
# │    └─Dropout: 2-9                                     [1, 256]                  --
# │    └─Linear: 2-10                                     [1, 4]                    (1,028)
# =========================================================================================================
# Total params: 96,946,560
# Trainable params: 0
# Non-trainable params: 96,946,560
# Total mult-adds (Units.GIGABYTES): 2.51
# =========================================================================================================
# Input size (MB): 0.06
# Forward/backward pass size (MB): 66.47
# Params size (MB): 246.06
# Estimated Total Size (MB): 312.59
# =========================================================================================================
#
# SER Phase 1a model summary saved successfully.

# %% [markdown]
# ## Phase 1 — FER Pre-Training (face-only)
#
# ### Architecture: DINOv2 ViT-B/14 + Temporal Self-Attention
#
# **Why DINOv2 over ConvNeXt V2?**
#
# | Property | ConvNeXt V2 Base | DINOv2 ViT-B/14 |
# |---|---|---|
# | Pretraining | Supervised IN-22k | Self-supervised LVD-142M (142M diverse images) |
# | Inductive bias | Strong (conv locality) | Weak (global self-attention) |
# | Facial feature quality | Good | Exceptional — ViTs trained with DINO develop emergent segmentation of facial parts |
# | Temporal modelling | External mean-pool | Native sequence format — each frame = token sequence |
# | Overfitting risk on small data | Low | Higher — mitigated by frozen backbone + temporal dropout |
#
# **Why Temporal Self-Attention?**
#
# The previous pipeline mean-pooled `N` frame features — a bag-of-frames approach that discards
# all information about *how* expressions evolve. Temporal Self-Attention treats the `T` CLS tokens
# as a sequence, letting the model learn that "neutral → slight raise → smile" = happy rather than
# treating each frame independently. This is the primary reason we expect visual to surpass audio.
#
# **Architecture flow:**
# ```
# Input (B, T, 3, 224, 224)
#   → reshape (B*T, 3, 224, 224)
#   → DINOv2 ViT-B/14  [frozen initially]
#   → CLS tokens: (B*T, 768)
#   → reshape (B, T, 768)
#   → positional encoding (learnable, T positions)
#   → Temporal Self-Attention (2 transformer layers, 8 heads)
#   → mean pool over T  →  (B, 768)
#   → LayerNorm + Dropout
#   → head: Linear(768→256) → GELU → Dropout → Linear(256→4)
# ```
#
# **Latency budget (3-second Streamlit demo):**
# - Frame extraction: ~0.3s (MediaPipe on 16 frames)
# - DINOv2 forward (B=1×16): ~0.15s on GPU
# - Temporal attention + head: ~0.01s
# - **Total visual path: ~0.5s** — well within 3s budget
#
# **Data-leakage note:** DINOv2 is pretrained on a general-purpose corpus (LVD-142M) with no overlap
# with RAVDESS. Temporal positional encodings are learned from scratch on training actors only.
# The frozen backbone itself carries no RAVDESS-specific information.

# %%
# Cell 12 — FER Model Architecture  [COMPLETELY REPLACED: DINOv2 + Temporal Attention]

class TemporalSelfAttention(nn.Module):
    """
    Lightweight 2-layer transformer encoder for modelling expression dynamics
    across DINOv2 frame CLS tokens.

    Design choices:
    - 2 layers: sufficient for 16 frames on a ~1k-sample dataset; deeper = overfit
    - 8 heads on dim=768: matches DINOv2 ViT-B internal attention width
    - Pre-LN (layer norm before attention): more stable for small datasets
    - Learnable positional encoding: lets model learn which frames are most
      informative (e.g., peak expression frames carry more weight than onset)
    - dropout=0.1 on attention weights: regularises temporal paths

    Input : (B, T, 768)
    Output: (B, T, 768)  — caller mean-pools over T
    """
    def __init__(self, dim: int = 768, n_heads: int = 8,
                 n_layers: int = 2, dropout: float = 0.1,
                 n_frames: int = NUM_FRAMES):
        super().__init__()
        self.pos_emb = nn.Parameter(torch.zeros(1, n_frames, dim))
        nn.init.trunc_normal_(self.pos_emb, std=0.02)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=dim,
            nhead=n_heads,
            dim_feedforward=dim * 2,   # compact FFN — 2× not 4×
            dropout=dropout,
            activation="gelu",
            batch_first=True,
            norm_first=True,           # Pre-LN for stability
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
        self.norm    = nn.LayerNorm(dim)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """x: (B, T, dim) → (B, T, dim)"""
        x = x + self.pos_emb[:, :x.size(1), :]
        x = self.encoder(x)
        return self.norm(x)


class FERModel(nn.Module):
    """
    Facial Emotion Recognition model  [v3: DINOv2 ViT-B/14 + Temporal Self-Attention]

    Replaces v2's ConvNeXt V2 Base + SE block + AdaptiveAvgPool.

    extract_features(x) accepts:
      - 5-D input (B, T, C, H, W) — clip (used by fusion)
      - 4-D input (B, C, H, W)    — single frame (edge case; repeats to T=1)
    Returns (B, VISUAL_DIM=768) for downstream gated fusion.
    """
    def __init__(self, n_class: int = 4, n_frames: int = NUM_FRAMES,
                 embed_dim: int = VISUAL_DIM, dropout: float = 0.4):
        super().__init__()

        # ── DINOv2 ViT-B/14  ─────────────────────────────────────────────────
        # timm identifier: vit_base_patch14_dinov2.lvd142m
        # img_size=224 → 16×16 = 256 spatial tokens + 1 CLS = 257 total
        # num_classes=0 → returns CLS token directly (shape: B, 768)
        self.backbone = timm.create_model(
            "vit_base_patch14_dinov2.lvd142m",
            pretrained=True,
            num_classes=0,        # no classification head — we use CLS token
            img_size=IMG_SIZE,    # 224
        )
        # Freeze all backbone params initially; Phase 1b will unfreeze last 4 blocks
        for p in self.backbone.parameters():
            p.requires_grad = False

        # ── Temporal Self-Attention  ──────────────────────────────────────────
        self.temporal_attn = TemporalSelfAttention(
            dim=embed_dim, n_heads=8, n_layers=2,
            dropout=0.1, n_frames=n_frames
        )

        # ── Classification head  ──────────────────────────────────────────────
        self.head_norm = nn.LayerNorm(embed_dim)
        self.dropout   = nn.Dropout(dropout)
        self.head = nn.Sequential(
            nn.Linear(embed_dim, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(256, n_class),
        )

        self.embed_dim = embed_dim
        self.n_frames  = n_frames

    def _extract_clip_features(self, clip: torch.Tensor) -> torch.Tensor:
        """
        clip: (B, T, C, H, W)
        Returns: (B, embed_dim)

        Steps:
          1. Flatten to (B*T, C, H, W) for efficient batched DINOv2 forward
          2. Extract CLS token → (B*T, 768)
          3. Reshape to (B, T, 768)
          4. Temporal self-attention → (B, T, 768)
          5. Mean pool over T → (B, 768)
        """
        B, T, C, H, W = clip.shape
        # ── step 1-2: batched DINOv2 forward ──────────────────────────────
        clip_flat = clip.view(B * T, C, H, W)        # (B*T, C, H, W)
        cls_flat  = self.backbone(clip_flat)           # (B*T, 768)
        # ── step 3: restore temporal axis ─────────────────────────────────
        cls_seq   = cls_flat.view(B, T, self.embed_dim)  # (B, T, 768)
        # ── step 4: temporal self-attention ───────────────────────────────
        ctx       = self.temporal_attn(cls_seq)           # (B, T, 768)
        # ── step 5: mean pool ─────────────────────────────────────────────
        z         = ctx.mean(dim=1)                        # (B, 768)
        return self.head_norm(z)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """x: (B, T, C, H, W) — returns logits (B, n_class)"""
        if x.dim() == 4:                   # single-frame fallback
            x = x.unsqueeze(1)
        z = self._extract_clip_features(x)
        return self.head(self.dropout(z))

    def extract_features(self, x: torch.Tensor) -> torch.Tensor:
        """Returns (B, 768) clip embedding for the gated fusion stage."""
        if x.dim() == 4:
            x = x.unsqueeze(1)
        return self._extract_clip_features(x)


fer_model = FERModel(n_class=NUM_CLASSES).to(DEVICE)
trainable = sum(p.numel() for p in fer_model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in fer_model.parameters())
print(f"FER model — trainable: {trainable:,} / total: {total:,}")
print(f"  Backbone (DINOv2 ViT-B/14) : frozen")
print(f"  Temporal Self-Attention    : trainable")
print(f"  Classification head        : trainable")

# Shape sanity-check
with torch.no_grad():
    dummy_clip = torch.randn(2, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE).to(DEVICE)
    out_logits = fer_model(dummy_clip)
    out_feats  = fer_model.extract_features(dummy_clip)
print(f"\nDummy forward — logits: {out_logits.shape} | features: {out_feats.shape}")
print(f"  Expected: logits ({2}, {NUM_CLASSES}) | features ({2}, {VISUAL_DIM})")
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# FER model — trainable: 9,667,844 / total: 95,392,772
#   Backbone (DINOv2 ViT-B/14) : frozen
#   Temporal Self-Attention    : trainable
#   Classification head        : trainable
#
# Dummy forward — logits: torch.Size([2, 4]) | features: torch.Size([2, 768])
#   Expected: logits (2, 4) | features (2, 768)

# %%
summary_fer1 = summary(
    fer_model,
    input_size=(1, 16, 3, 224, 224),
    device=DEVICE
)

summary_fer1

summary_str = str(summary_fer1)

# Print in notebook
print(summary_str)

# ===== Save summary as TXT =====
with open(" FER Model Architecture  [COMPLETELY REPLACED: DINOv2 + Temporal Attention].txt", "w") as f:
    f.write(summary_str)

# ===== Save summary as PNG =====
plt.figure(figsize=(24, 30))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=8,
    va='top'
)

plt.axis('off')

plt.savefig(
    " FER_Model_Architecture_[COMPLETELY_REPLACED:_DINOv2_+_Temporal_Attention].png",
    dpi=1200,
    bbox_inches='tight'
)

plt.close()

print("\n FER Model Architecture  [COMPLETELY REPLACED: DINOv2 + Temporal Attention].")
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# FERModel                                                [1, 4]                    --
# ├─VisionTransformer: 1-1                                [16, 768]                 198,144
# │    └─PatchEmbed: 2-1                                  [16, 256, 768]            --
# │    │    └─Conv2d: 3-1                                 [16, 768, 16, 16]         (452,352)
# │    │    └─Identity: 3-2                               [16, 256, 768]            --
# │    └─Dropout: 2-2                                     [16, 257, 768]            --
# │    └─Identity: 2-3                                    [16, 257, 768]            --
# │    └─Identity: 2-4                                    [16, 257, 768]            --
# │    └─Sequential: 2-5                                  [16, 257, 768]            --
# │    │    └─Block: 3-3                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-4                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-5                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-6                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-7                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-8                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-9                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-10                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-11                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-12                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-13                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-14                                 [16, 257, 768]            (7,089,408)
# │    └─LayerNorm: 2-6                                   [16, 257, 768]            (1,536)
# │    └─Identity: 2-7                                    [16, 768]                 --
# │    └─Dropout: 2-8                                     [16, 768]                 --
# │    └─Identity: 2-9                                    [16, 768]                 --
# ├─TemporalSelfAttention: 1-2                            [1, 16, 768]              12,288
# │    └─TransformerEncoder: 2-10                         [1, 16, 768]              --
# │    │    └─ModuleList: 3-15                            --                        9,454,080
# │    └─LayerNorm: 2-11                                  [1, 16, 768]              1,536
# ├─LayerNorm: 1-3                                        [1, 768]                  1,536
# ├─Dropout: 1-4                                          [1, 768]                  --
# ├─Sequential: 1-5                                       [1, 4]                    --
# │    └─Linear: 2-12                                     [1, 256]                  196,864
# │    └─LayerNorm: 2-13                                  [1, 256]                  512
# │    └─GELU: 2-14                                       [1, 256]                  --
# │    └─Dropout: 2-15                                    [1, 256]                  --
# │    └─Linear: 2-16                                     [1, 4]                    1,028
# =========================================================================================================
# Total params: 95,392,772
# Trainable params: 9,667,844
# Non-trainable params: 85,724,928
# Total mult-adds (Units.GIGABYTES): 3.22
# =========================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 3992.73
# Params size (MB): 361.83
# Estimated Total Size (MB): 4364.19
# =========================================================================================================
#
#  FER Model Architecture  [COMPLETELY REPLACED: DINOv2 + Temporal Attention].

# %%
# Cell 13 — FER Phase 1a: Train temporal head only (DINOv2 frozen)
#
# v3 training loop change: imgs is now (B, T, C, H, W) instead of (B, C, H, W).
# The model's forward() handles the temporal dim internally — no loop change needed
# beyond accepting the new shape.

fer_train_loader, fer_val_loader, fer_test_loader = make_loaders(
    train_df, val_df, test_df,
    FaceOnlyDataset,
    kwargs_train={"video_tf": video_tf_train, "augment": True},
    kwargs_eval ={"video_tf": video_tf_eval,  "augment": False},
    batch_size=FER_BATCH_SIZE
)

def train_epoch_fer(model, loader, optimizer, criterion, scaler):
    """FER training — imgs shape: (B, T, C, H, W)."""
    model.train()
    total_loss, correct, total = 0, 0, 0
    for clips, labels in tqdm(loader, desc="FER train", leave=False):
        clips, labels = clips.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        with autocast():
            logits = model(clips)            # clips: (B, T, C, H, W)
            loss   = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_([p for p in model.parameters() if p.requires_grad], GRAD_CLIP)
        scaler.step(optimizer); scaler.update()
        total_loss += loss.item() * labels.size(0)
        correct    += (logits.argmax(1) == labels).sum().item()
        total      += labels.size(0)
    return total_loss / total, correct / total

@torch.no_grad()
def eval_fer(model, loader, criterion):
    model.eval()
    total_loss, all_preds, all_labels = 0, [], []
    for clips, labels in tqdm(loader, desc="FER eval", leave=False):
        clips, labels = clips.to(DEVICE), labels.to(DEVICE)
        with autocast():
            logits = model(clips)
            loss   = criterion(logits, labels)
        total_loss += loss.item() * labels.size(0)
        all_preds.extend(logits.argmax(1).cpu().tolist())
        all_labels.extend(labels.cpu().tolist())
    p, l = np.array(all_preds), np.array(all_labels)
    return {
        "loss": total_loss / len(l),
        "acc" : accuracy_score(l, p),
        "uar" : recall_score(l, p, average="macro"),
        "f1"  : f1_score(l, p, average="macro"),
    }

criterion_fer = nn.CrossEntropyLoss(label_smoothing=0.1)
opt_fer       = AdamW([p for p in fer_model.parameters() if p.requires_grad],
                       lr=FER_LR, weight_decay=FER_WEIGHT_DECAY)
sch_fer       = CosineAnnealingWarmRestarts(opt_fer, T_0=10, eta_min=1e-6)
scaler_fer    = GradScaler()
FER_CKPT      = os.path.join(SAVE_DIR, "fer_pretrained.pt")

best_uar_fer, patience_fer = 0.0, 0
print("FER Phase 1a — temporal head + pos-enc (DINOv2 frozen)")
for epoch in range(1, FER_EPOCHS + 1):
    tr_loss, tr_acc = train_epoch_fer(fer_model, fer_train_loader, opt_fer, criterion_fer, scaler_fer)
    val_m           = eval_fer(fer_model, fer_val_loader, criterion_fer)
    sch_fer.step()
    print(f"Ep {epoch:02d}/{FER_EPOCHS}  train_acc={tr_acc:.4f} | val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}")
    if val_m["uar"] > best_uar_fer:
        best_uar_fer, patience_fer = val_m["uar"], 0
        torch.save(fer_model.state_dict(), FER_CKPT)
        print(f"  ✓ Best UAR={best_uar_fer:.4f}")
    else:
        patience_fer += 1
        if patience_fer >= PATIENCE: print("Early stop (FER 1a)."); break

print(f"Phase 1a done. Best UAR={best_uar_fer:.4f}")
# Out:
# FER Phase 1a — temporal head + pos-enc (DINOv2 frozen)
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 01/20  train_acc=0.5260 | val_acc=0.6806  val_uar=0.6458
#   ✓ Best UAR=0.6458
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 02/20  train_acc=0.7326 | val_acc=0.6389  val_uar=0.6042
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 03/20  train_acc=0.8194 | val_acc=0.6528  val_uar=0.6198
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 04/20  train_acc=0.8715 | val_acc=0.5972  val_uar=0.5469
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 05/20  train_acc=0.8663 | val_acc=0.6389  val_uar=0.5990
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 06/20  train_acc=0.9062 | val_acc=0.6250  val_uar=0.5885
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 07/20  train_acc=0.9323 | val_acc=0.6250  val_uar=0.5938
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 08/20  train_acc=0.9219 | val_acc=0.6528  val_uar=0.6250
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# Ep 09/20  train_acc=0.9323 | val_acc=0.6389  val_uar=0.6094
# Early stop (FER 1a).
# Phase 1a done. Best UAR=0.6458

# %%
# summary_fer1 = summary(
#     fer_model,
#     input_size=(1, 16, 3, 224, 224),
#     device=DEVICE
# )

# summary_fer1

# summary_str = str(summary_fer1)

# # Print in notebook
# print(summary_str)

# # ===== Save summary as TXT =====
# with open("FER_Phase1a_Model_Summary.txt", "w") as f:
#     f.write(summary_str)

# # ===== Save summary as PNG =====
# plt.figure(figsize=(24, 30))

# plt.text(
#     0.01,
#     0.99,
#     summary_str,
#     family='monospace',
#     fontsize=8,
#     va='top'
# )

# plt.axis('off')

# plt.savefig(
#     "FER_Phase1a_Model_Summary.png",
#     dpi=1200,
#     bbox_inches='tight'
# )

# plt.close()

# print("\nFER Phase 1a model summary saved successfully.")

# %%
# from torchinfo import summary
# import matplotlib.pyplot as plt

# # ===== Generate FER model summary =====
# summary_fer_phase1a = summary(
#     fer_model,
#     input_size=(1, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE),
#     device=DEVICE,
#     verbose=0
# )

# # Convert summary to string
# summary_str = str(summary_fer_phase1a)

# # Print in notebook
# print(summary_str)

# # ===== Save summary as TXT =====
# with open("FER_Phase1a_Model_Summary.txt", "w") as f:
#     f.write(summary_str)

# # ===== Save summary as PNG =====
# plt.figure(figsize=(24, 30))

# plt.text(
#     0.01,
#     0.99,
#     summary_str,
#     family='monospace',
#     fontsize=8,
#     va='top'
# )

# plt.axis('off')

# plt.savefig(
#     "FER_Phase1a_Model_Summary.png",
#     dpi=1200,
#     bbox_inches='tight'
# )

# plt.close()

# print("\nFER Phase 1a model summary saved successfully.")

# %%
# Cell 14 — FER Phase 1b: Unfreeze last 4 ViT transformer blocks
#
# v2 unfroze the last 2 ConvNeXt stages (named `.stages[-1]`, `.stages[-2]`).
# DINOv2 ViT-B/14 has 12 transformer blocks (`.blocks[0]...[11]`).
# We unfreeze the last 4 (blocks 8-11) — enough for facial fine-tuning
# without destroying the rich low-level patch features in early blocks.
#
# We also unfreeze the backbone's final LayerNorm (`norm`) so that
# the CLS token distribution adapts to expression-specific activation patterns.
#
# LR schedule:
#   - Unfrozen ViT blocks : very small (1e-6) — these weights are already near-optimal
#   - Temporal attention  : moderate (2e-5) — still adapting
#   - Head                : moderate (5e-5) — fastest to converge

fer_model.load_state_dict(torch.load(FER_CKPT, map_location=DEVICE))

# Unfreeze last 4 transformer blocks (indices 8, 9, 10, 11)
n_blocks = len(fer_model.backbone.blocks)
print(f"DINOv2 ViT-B/14 has {n_blocks} transformer blocks")
for blk in fer_model.backbone.blocks[-4:]:
    for p in blk.parameters():
        p.requires_grad = True

# Also unfreeze backbone final LayerNorm
for p in fer_model.backbone.norm.parameters():
    p.requires_grad = True

unf = sum(p.numel() for p in fer_model.parameters() if p.requires_grad)
print(f"FER Phase 1b — trainable after unfreeze: {unf:,}")

opt_fer2 = AdamW([
    # Unfrozen ViT blocks + norm: very conservative LR
    {"params": [p for n, p in fer_model.named_parameters()
                if p.requires_grad and "backbone" in n], "lr": 1e-6},
    # Temporal attention positional embeddings + encoder
    {"params": [p for n, p in fer_model.named_parameters()
                if p.requires_grad and "temporal_attn" in n], "lr": 2e-5},
    # Classification head
    {"params": [p for n, p in fer_model.named_parameters()
                if p.requires_grad and ("head" in n or "dropout" in n)], "lr": 5e-5},
], weight_decay=FER_WEIGHT_DECAY)

sch_fer2    = CosineAnnealingWarmRestarts(opt_fer2, T_0=5, eta_min=1e-7)
scaler_fer2 = GradScaler()
FER_CKPT_FT = os.path.join(SAVE_DIR, "fer_finetuned.pt")

best_uar_fer2, patience_fer2 = best_uar_fer, 0
for epoch in range(1, 11):
    tr_loss, tr_acc = train_epoch_fer(fer_model, fer_train_loader, opt_fer2, criterion_fer, scaler_fer2)
    val_m           = eval_fer(fer_model, fer_val_loader, criterion_fer)
    sch_fer2.step()
    print(f"1b Ep {epoch:02d}/10  train_acc={tr_acc:.4f} | val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}")
    if val_m["uar"] > best_uar_fer2:
        best_uar_fer2, patience_fer2 = val_m["uar"], 0
        torch.save(fer_model.state_dict(), FER_CKPT_FT)
        print(f"  ✓ Best UAR={best_uar_fer2:.4f}")
    else:
        patience_fer2 += 1
        if patience_fer2 >= 5: print("Early stop (FER 1b)."); break

best_fer_ckpt = FER_CKPT_FT if os.path.exists(FER_CKPT_FT) else FER_CKPT
fer_model.load_state_dict(torch.load(best_fer_ckpt, map_location=DEVICE))
fer_model.eval()
for p in fer_model.parameters(): p.requires_grad = False

test_fer = eval_fer(fer_model, fer_test_loader, criterion_fer)
print(f"\nFER Test — Acc={test_fer['acc']:.4f}  UAR={test_fer['uar']:.4f}  F1={test_fer['f1']:.4f}")
print("FER backbone frozen for fusion stage.")
# Out:
# DINOv2 ViT-B/14 has 12 transformer blocks
# FER Phase 1b — trainable after unfreeze: 38,027,012
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# 1b Ep 01/10  train_acc=0.7170 | val_acc=0.5278  val_uar=0.4688
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# 1b Ep 02/10  train_acc=0.8281 | val_acc=0.6667  val_uar=0.6250
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# 1b Ep 03/10  train_acc=0.8663 | val_acc=0.6389  val_uar=0.6146
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# 1b Ep 04/10  train_acc=0.8681 | val_acc=0.5972  val_uar=0.5625
# FER train:   0%|          | 0/72 [00:00<?, ?it/s]
# FER eval:   0%|          | 0/9 [00:00<?, ?it/s]
# 1b Ep 05/10  train_acc=0.8924 | val_acc=0.6250  val_uar=0.5938
# Early stop (FER 1b).
# FER eval:   0%|          | 0/27 [00:00<?, ?it/s]
# FER Test — Acc=0.7130  UAR=0.7413  F1=0.7311
# FER backbone frozen for fusion stage.

# %%
summary_fer = summary(
    fer_model,
    input_size=(1, 16, 3, 224, 224),
    device=DEVICE
)

summary_fer

summary_str = str(summary_fer)

# Print in notebook
print(summary_str)

# ===== Save summary as TXT =====
with open("FER_Phase1b_unfreezen_Model_Summary.txt", "w") as f:
    f.write(summary_str)

# ===== Save summary as PNG =====
plt.figure(figsize=(24, 30))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=8,
    va='top'
)

plt.axis('off')

plt.savefig(
    "FER_Phase1b_unfreezen_Model_Summary.png",
    dpi=1200,
    bbox_inches='tight'
)

plt.close()

print("\nFER Phase 1b unfreezen model summary saved successfully.")
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# FERModel                                                [1, 4]                    --
# ├─VisionTransformer: 1-1                                [16, 768]                 198,144
# │    └─PatchEmbed: 2-1                                  [16, 256, 768]            --
# │    │    └─Conv2d: 3-1                                 [16, 768, 16, 16]         (452,352)
# │    │    └─Identity: 3-2                               [16, 256, 768]            --
# │    └─Dropout: 2-2                                     [16, 257, 768]            --
# │    └─Identity: 2-3                                    [16, 257, 768]            --
# │    └─Identity: 2-4                                    [16, 257, 768]            --
# │    └─Sequential: 2-5                                  [16, 257, 768]            --
# │    │    └─Block: 3-3                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-4                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-5                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-6                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-7                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-8                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-9                                  [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-10                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-11                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-12                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-13                                 [16, 257, 768]            (7,089,408)
# │    │    └─Block: 3-14                                 [16, 257, 768]            (7,089,408)
# │    └─LayerNorm: 2-6                                   [16, 257, 768]            (1,536)
# │    └─Identity: 2-7                                    [16, 768]                 --
# │    └─Dropout: 2-8                                     [16, 768]                 --
# │    └─Identity: 2-9                                    [16, 768]                 --
# ├─TemporalSelfAttention: 1-2                            [1, 16, 768]              12,288
# │    └─TransformerEncoder: 2-10                         [1, 16, 768]              --
# │    │    └─ModuleList: 3-15                            --                        (9,454,080)
# │    └─LayerNorm: 2-11                                  [1, 16, 768]              (1,536)
# ├─LayerNorm: 1-3                                        [1, 768]                  (1,536)
# ├─Dropout: 1-4                                          [1, 768]                  --
# ├─Sequential: 1-5                                       [1, 4]                    --
# │    └─Linear: 2-12                                     [1, 256]                  (196,864)
# │    └─LayerNorm: 2-13                                  [1, 256]                  (512)
# │    └─GELU: 2-14                                       [1, 256]                  --
# │    └─Dropout: 2-15                                    [1, 256]                  --
# │    └─Linear: 2-16                                     [1, 4]                    (1,028)
# =========================================================================================================
# Total params: 95,392,772
# Trainable params: 0
# Non-trainable params: 95,392,772
# Total mult-adds (Units.GIGABYTES): 3.22
# =========================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 3992.73
# Params size (MB): 361.83
# Estimated Total Size (MB): 4364.19
# =========================================================================================================
#
# FER Phase 1b unfreezen model summary saved successfully.

# %% [markdown]
# ## Phase 2 — Gated Fusion Training
#
# **Architecture is identical to v2.** The only numerical change is `visual_dim = 768`
# (was 1024) since DINOv2 ViT-B outputs 768-dim vs ConvNeXt V2's 1024-dim.
#
# The GatedFusion class, MultimodalEmotionModel structure, training loop, and
# early-stopping logic are all unchanged.

# %%
# Cell 15 — Gated Fusion Architecture  [UNCHANGED logic; visual_dim updated: 1024 → 768]

class GatedFusion(nn.Module):
    """
    Gated Multimodal Fusion (Arevalo et al., 2017).
    z = sigmoid(W[h_audio || h_visual])
    fused = z * h_audio + (1 - z) * h_visual
    Per-sample, per-dimension gating — model learns which modality to trust.
    [UNCHANGED from v2 — only visual_dim default updated]
    """
    def __init__(self, audio_dim: int = 768, visual_dim: int = VISUAL_DIM,
                 fusion_dim: int = 512, dropout: float = 0.3):
        super().__init__()
        self.audio_proj  = nn.Sequential(
            nn.Linear(audio_dim, fusion_dim), nn.LayerNorm(fusion_dim), nn.GELU()
        )
        self.visual_proj = nn.Sequential(
            nn.Linear(visual_dim, fusion_dim), nn.LayerNorm(fusion_dim), nn.GELU()
        )
        self.gate    = nn.Sequential(
            nn.Linear(fusion_dim * 2, fusion_dim), nn.Sigmoid()
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, h_a, h_v, return_gate=False):
        a = self.audio_proj(h_a)
        v = self.visual_proj(h_v)
        z = self.gate(torch.cat([a, v], dim=-1))
        fused = self.dropout(z * a + (1 - z) * v)
        return (fused, z) if return_gate else fused


class MultimodalEmotionModel(nn.Module):
    """
    Full multimodal model:
      audio → SERModel (frozen, RAVDESS fine-tuned)  → 768d
      clip  → FERModel (frozen, RAVDESS fine-tuned)  → 768d  [v3: temporal path included]
      → GatedFusion → 512d → Classifier → 4 classes

    Key v3 change: FER's extract_features() now accepts (B, T, C, H, W) and
    handles the temporal dimension internally. The fusion stage no longer needs
    to manually reshape and mean-pool frame features.
    """
    def __init__(self, ser: nn.Module, fer: nn.Module,
                 fusion_dim: int = FUSION_DIM, n_classes: int = NUM_CLASSES,
                 dropout: float = DROPOUT):
        super().__init__()
        self.ser    = ser
        self.fer    = fer
        self.fusion = GatedFusion(
            audio_dim=768, visual_dim=VISUAL_DIM,
            fusion_dim=fusion_dim, dropout=dropout
        )
        self.classifier = nn.Sequential(
            nn.Linear(fusion_dim, 256), nn.LayerNorm(256), nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(256, n_classes),
        )

    def forward(self, wav: torch.Tensor, clip: torch.Tensor,
                return_gate: bool = False):
        """
        wav  : (B, MAX_SAMPLES)
        clip : (B, T, C, H, W)
        """
        with torch.no_grad():
            h_a = self.ser.extract_features(wav)    # (B, 768)
            h_v = self.fer.extract_features(clip)   # (B, 768) — temporal handled inside FER

        if return_gate:
            fused, gate = self.fusion(h_a, h_v, return_gate=True)
            return self.classifier(fused), gate
        return self.classifier(self.fusion(h_a, h_v))


model = MultimodalEmotionModel(
    ser=ser_model, fer=fer_model,
    fusion_dim=FUSION_DIM, n_classes=NUM_CLASSES, dropout=DROPOUT
).to(DEVICE)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model.parameters())
print(f"Fusion model — trainable: {trainable:,} / total: {total:,}")
print("  (Only fusion + classifier params are trained — both backbones frozen)")

# Shape sanity-check
with torch.no_grad():
    wav_t  = torch.randn(2, MAX_SAMPLES).to(DEVICE)
    clip_t = torch.randn(2, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE).to(DEVICE)
    out    = model(wav_t, clip_t)
print(f"Fusion output shape: {out.shape}  — expected (2, {NUM_CLASSES})")
# Out:
# Fusion model — trainable: 1,447,172 / total: 193,786,504
#   (Only fusion + classifier params are trained — both backbones frozen)
# Fusion output shape: torch.Size([2, 4])  — expected (2, 4)

# %%
# from torchinfo import summary

# summary_fusion = summary(
#     model,
#     input_data=[
#         torch.randn(1, MAX_SAMPLES).to(DEVICE),                 # wav
#         torch.randn(1, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE).to(DEVICE)  # clip
#     ],
#     device=DEVICE,
#     verbose=0
# )

# print(summary_fusion)

# %%
# import matplotlib.pyplot as plt

# # Convert to string
# summary_str = str(summary_fusion)

# # ===== Save TXT =====
# with open("Fusion_Model_Summary.txt", "w") as f:
#     f.write(summary_str)

# # ===== Save PNG =====
# plt.figure(figsize=(26, 32))

# plt.text(
#     0.01,
#     0.99,
#     summary_str,
#     family='monospace',
#     fontsize=8,
#     va='top'
# )

# plt.axis('off')

# plt.savefig(
#     "Fusion_Model_Summary.png",
#     dpi=300,
#     bbox_inches='tight'
# )

# plt.close()

# print("Fusion model summary saved successfully.")

# %%
# Cell 16 — Fusion Training Loop  [UNCHANGED from v2]

mm_train_loader, mm_val_loader, mm_test_loader = make_loaders(
    train_df, val_df, test_df,
    MultimodalDataset,
    kwargs_train={"video_tf": video_tf_train, "augment": True},
    kwargs_eval ={"video_tf": video_tf_eval,  "augment": False},
    batch_size=BATCH_SIZE
)

def train_epoch_mm(model, loader, optimizer, criterion, scaler):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for wav, clip, labels in tqdm(loader, desc="Fusion train", leave=False):
        wav, clip, labels = wav.to(DEVICE), clip.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        with autocast():
            logits = model(wav, clip)
            loss   = criterion(logits, labels)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_([p for p in model.parameters() if p.requires_grad], GRAD_CLIP)
        scaler.step(optimizer); scaler.update()
        total_loss += loss.item() * labels.size(0)
        correct    += (logits.argmax(1) == labels).sum().item()
        total      += labels.size(0)
    return total_loss / total, correct / total

@torch.no_grad()
def eval_mm(model, loader, criterion):
    model.eval()
    total_loss, all_preds, all_labels = 0, [], []
    for wav, clip, labels in tqdm(loader, desc="Fusion eval", leave=False):
        wav, clip, labels = wav.to(DEVICE), clip.to(DEVICE), labels.to(DEVICE)
        with autocast():
            logits = model(wav, clip)
            loss   = criterion(logits, labels)
        total_loss += loss.item() * labels.size(0)
        all_preds.extend(logits.argmax(1).cpu().tolist())
        all_labels.extend(labels.cpu().tolist())
    p, l = np.array(all_preds), np.array(all_labels)
    return {
        "loss": total_loss / len(l),
        "acc" : accuracy_score(l, p),
        "uar" : recall_score(l, p, average="macro"),
        "f1"  : f1_score(l, p, average="macro"),
        "preds": p, "labels": l,
    }

criterion  = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTH)
opt_mm     = AdamW([p for p in model.parameters() if p.requires_grad],
                    lr=FUSION_LR, weight_decay=WEIGHT_DECAY)
sch_mm     = CosineAnnealingWarmRestarts(opt_mm, T_0=10, T_mult=2, eta_min=1e-6)
scaler_mm  = GradScaler()
FUSION_CKPT = os.path.join(SAVE_DIR, "best_fusion.pt")

history = {k: [] for k in ["train_loss","train_acc","val_loss","val_acc","val_uar","val_f1"]}
best_uar_mm, patience_mm = 0.0, 0

print("Phase 2 — Gated Fusion Training")
for epoch in range(1, EPOCHS + 1):
    tr_loss, tr_acc = train_epoch_mm(model, mm_train_loader, opt_mm, criterion, scaler_mm)
    val_m           = eval_mm(model, mm_val_loader, criterion)
    sch_mm.step()

    for k, v in zip(
        ["train_loss","train_acc","val_loss","val_acc","val_uar","val_f1"],
        [tr_loss, tr_acc, val_m["loss"], val_m["acc"], val_m["uar"], val_m["f1"]]
    ):
        history[k].append(v)

    print(f"Ep {epoch:02d}/{EPOCHS}  train_acc={tr_acc:.4f} | val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}  val_f1={val_m['f1']:.4f}")

    if val_m["uar"] > best_uar_mm:
        best_uar_mm, patience_mm = val_m["uar"], 0
        torch.save({
            "epoch"       : epoch,
            "fusion_state": {k: v for k, v in model.state_dict().items()
                             if "ser" not in k and "fer" not in k},
            "val_uar"     : best_uar_mm,
            "val_acc"     : val_m["acc"],
        }, FUSION_CKPT)
        print(f"  ✓ Best UAR={best_uar_mm:.4f} saved.")
    else:
        patience_mm += 1
        if patience_mm >= PATIENCE: print(f"Early stop at epoch {epoch}."); break

print(f"\nPhase 2 done. Best UAR={best_uar_mm:.4f}")
# Out:
# Phase 2 — Gated Fusion Training
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 01/30  train_acc=0.8854 | val_acc=0.9306  val_uar=0.9271  val_f1=0.9324
#   ✓ Best UAR=0.9271 saved.
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 02/30  train_acc=0.9358 | val_acc=0.9167  val_uar=0.9115  val_f1=0.9174
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 03/30  train_acc=0.9566 | val_acc=0.8611  val_uar=0.8438  val_f1=0.8549
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 04/30  train_acc=0.9566 | val_acc=0.9306  val_uar=0.9323  val_f1=0.9299
#   ✓ Best UAR=0.9323 saved.
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 05/30  train_acc=0.9497 | val_acc=0.9028  val_uar=0.8906  val_f1=0.8987
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 06/30  train_acc=0.9757 | val_acc=0.9167  val_uar=0.9062  val_f1=0.9165
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 07/30  train_acc=0.9757 | val_acc=0.8750  val_uar=0.8698  val_f1=0.8785
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 08/30  train_acc=0.9722 | val_acc=0.8056  val_uar=0.7917  val_f1=0.8058
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 09/30  train_acc=0.9809 | val_acc=0.8194  val_uar=0.8073  val_f1=0.8226
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 10/30  train_acc=0.9878 | val_acc=0.8194  val_uar=0.8073  val_f1=0.8226
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 11/30  train_acc=0.9583 | val_acc=0.8333  val_uar=0.8229  val_f1=0.8370
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# Ep 12/30  train_acc=0.9688 | val_acc=0.8750  val_uar=0.8594  val_f1=0.8768
# Early stop at epoch 12.
#
# Phase 2 done. Best UAR=0.9323

# %%
from torchinfo import summary
import matplotlib.pyplot as plt

# ===== Generate summary =====
from torchinfo import summary
import torch

model.eval()
torch.set_grad_enabled(False)

summary_mm = summary(
    model,
    input_size=[
        (1, MAX_SAMPLES),
        (1, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE)
    ],
    device=DEVICE,
    verbose=0,
    col_names=[
        "input_size",
        "output_size",
        "num_params"
    ]
)

print(summary_mm)

# Convert summary to string
summary_str = str(summary_mm)

# Print summary in notebook
print(summary_str)

# ===== Save TXT =====
with open("Fusion_Phase2_Model_Summary.txt", "w") as f:
    f.write(summary_str)

# ===== Save PNG =====
plt.figure(figsize=(28, 36))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=8,
    va='top'
)

plt.axis('off')

plt.savefig(
    "Fusion_Phase2_Model_Summary.png",
    dpi=300,
    bbox_inches='tight'
)

plt.close()

print("\nFusion Phase 2 model summary saved successfully.")
# Out:
# =======================================================================================================================================
# Layer (type:depth-idx)                                       Input Shape               Output Shape              Param #
# =======================================================================================================================================
# MultimodalEmotionModel                                       [1, 56000]                [1, 4]                    --
# ├─SERModel: 1-1                                              --                        --                        198,404
# │    └─WavLMModel: 2-1                                       [1, 56000]                [1, 174, 768]             768
# │    │    └─WavLMFeatureEncoder: 3-1                         [1, 56000]                [1, 512, 174]             (4,200,448)
# │    │    └─WavLMFeatureProjection: 3-2                      [1, 174, 512]             [1, 174, 768]             (395,008)
# │    │    └─WavLMEncoder: 3-3                                [1, 174, 768]             [1, 174, 768]             (89,785,712)
# │    └─WeightedLayerFusion: 2-2                              [1, 174, 768]             [1, 174, 768]             (12)
# │    └─SpeakerNorm: 2-3                                      [1, 174, 768]             [1, 174, 768]             --
# │    │    └─InstanceNorm1d: 3-4                              [1, 768, 174]             [1, 768, 174]             (1,536)
# │    └─AttentionPooling: 2-4                                 [1, 174, 768]             [1, 768]                  768
# │    │    └─MultiheadAttention: 3-5                          [1, 1, 768]               [1, 1, 768]               (2,362,368)
# │    └─LayerNorm: 2-5                                        [1, 768]                  [1, 768]                  (1,536)
# ├─FERModel: 1-2                                              --                        --                        198,404
# │    └─VisionTransformer: 2-6                                [16, 3, 224, 224]         [16, 768]                 198,144
# │    │    └─PatchEmbed: 3-6                                  [16, 3, 224, 224]         [16, 256, 768]            (452,352)
# │    │    └─Dropout: 3-7                                     [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-8                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-9                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Sequential: 3-10                                 [16, 257, 768]            [16, 257, 768]            (85,072,896)
# │    │    └─LayerNorm: 3-11                                  [16, 257, 768]            [16, 257, 768]            (1,536)
# │    │    └─Identity: 3-12                                   [16, 768]                 [16, 768]                 --
# │    │    └─Dropout: 3-13                                    [16, 768]                 [16, 768]                 --
# │    │    └─Identity: 3-14                                   [16, 768]                 [16, 768]                 --
# │    └─TemporalSelfAttention: 2-7                            [1, 16, 768]              [1, 16, 768]              12,288
# │    │    └─TransformerEncoder: 3-15                         [1, 16, 768]              [1, 16, 768]              (9,454,080)
# │    │    └─LayerNorm: 3-16                                  [1, 16, 768]              [1, 16, 768]              (1,536)
# │    └─LayerNorm: 2-8                                        [1, 768]                  [1, 768]                  (1,536)
# ├─GatedFusion: 1-3                                           [1, 768]                  [1, 512]                  --
# │    └─Sequential: 2-9                                       [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-17                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-18                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-19                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-10                                      [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-20                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-21                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-22                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-11                                      [1, 1024]                 [1, 512]                  --
# │    │    └─Linear: 3-23                                     [1, 1024]                 [1, 512]                  524,800
# │    │    └─Sigmoid: 3-24                                    [1, 512]                  [1, 512]                  --
# │    └─Dropout: 2-12                                         [1, 512]                  [1, 512]                  --
# ├─Sequential: 1-4                                            [1, 512]                  [1, 4]                    --
# │    └─Linear: 2-13                                          [1, 512]                  [1, 256]                  131,328
# │    └─LayerNorm: 2-14                                       [1, 256]                  [1, 256]                  512
# │    └─GELU: 2-15                                            [1, 256]                  [1, 256]                  --
# │    └─Dropout: 2-16                                         [1, 256]                  [1, 256]                  --
# │    └─Linear: 2-17                                          [1, 256]                  [1, 4]                    1,028
# =======================================================================================================================================
# Total params: 193,786,504
# Trainable params: 1,447,172
# Non-trainable params: 192,339,332
# Total mult-adds (Units.GIGABYTES): 11.86
# =======================================================================================================================================
# Input size (MB): 9.86
# Forward/backward pass size (MB): 4228.93
# Params size (MB): 612.09
# Estimated Total Size (MB): 4850.88
# =======================================================================================================================================
# =======================================================================================================================================
# Layer (type:depth-idx)                                       Input Shape               Output Shape              Param #
# =======================================================================================================================================
# MultimodalEmotionModel                                       [1, 56000]                [1, 4]                    --
# ├─SERModel: 1-1                                              --                        --                        198,404
# │    └─WavLMModel: 2-1                                       [1, 56000]                [1, 174, 768]             768
# │    │    └─WavLMFeatureEncoder: 3-1                         [1, 56000]                [1, 512, 174]             (4,200,448)
# │    │    └─WavLMFeatureProjection: 3-2                      [1, 174, 512]             [1, 174, 768]             (395,008)
# │    │    └─WavLMEncoder: 3-3                                [1, 174, 768]             [1, 174, 768]             (89,785,712)
# │    └─WeightedLayerFusion: 2-2                              [1, 174, 768]             [1, 174, 768]             (12)
# │    └─SpeakerNorm: 2-3                                      [1, 174, 768]             [1, 174, 768]             --
# │    │    └─InstanceNorm1d: 3-4                              [1, 768, 174]             [1, 768, 174]             (1,536)
# │    └─AttentionPooling: 2-4                                 [1, 174, 768]             [1, 768]                  768
# │    │    └─MultiheadAttention: 3-5                          [1, 1, 768]               [1, 1, 768]               (2,362,368)
# │    └─LayerNorm: 2-5                                        [1, 768]                  [1, 768]                  (1,536)
# ├─FERModel: 1-2                                              --                        --                        198,404
# │    └─VisionTransformer: 2-6                                [16, 3, 224, 224]         [16, 768]                 198,144
# │    │    └─PatchEmbed: 3-6                                  [16, 3, 224, 224]         [16, 256, 768]            (452,352)
# │    │    └─Dropout: 3-7                                     [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-8                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-9                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Sequential: 3-10                                 [16, 257, 768]            [16, 257, 768]            (85,072,896)
# │    │    └─LayerNorm: 3-11                                  [16, 257, 768]            [16, 257, 768]            (1,536)
# │    │    └─Identity: 3-12                                   [16, 768]                 [16, 768]                 --
# │    │    └─Dropout: 3-13                                    [16, 768]                 [16, 768]                 --
# │    │    └─Identity: 3-14                                   [16, 768]                 [16, 768]                 --
# │    └─TemporalSelfAttention: 2-7                            [1, 16, 768]              [1, 16, 768]              12,288
# │    │    └─TransformerEncoder: 3-15                         [1, 16, 768]              [1, 16, 768]              (9,454,080)
# │    │    └─LayerNorm: 3-16                                  [1, 16, 768]              [1, 16, 768]              (1,536)
# │    └─LayerNorm: 2-8                                        [1, 768]                  [1, 768]                  (1,536)
# ├─GatedFusion: 1-3                                           [1, 768]                  [1, 512]                  --
# │    └─Sequential: 2-9                                       [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-17                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-18                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-19                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-10                                      [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-20                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-21                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-22                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-11                                      [1, 1024]                 [1, 512]                  --
# │    │    └─Linear: 3-23                                     [1, 1024]                 [1, 512]                  524,800
# │    │    └─Sigmoid: 3-24                                    [1, 512]                  [1, 512]                  --
# │    └─Dropout: 2-12                                         [1, 512]                  [1, 512]                  --
# ├─Sequential: 1-4                                            [1, 512]                  [1, 4]                    --
# │    └─Linear: 2-13                                          [1, 512]                  [1, 256]                  131,328
# │    └─LayerNorm: 2-14                                       [1, 256]                  [1, 256]                  512
# │    └─GELU: 2-15                                            [1, 256]                  [1, 256]                  --
# │    └─Dropout: 2-16                                         [1, 256]                  [1, 256]                  --
# │    └─Linear: 2-17                                          [1, 256]                  [1, 4]                    1,028
# =======================================================================================================================================
# Total params: 193,786,504
# Trainable params: 1,447,172
# Non-trainable params: 192,339,332
# Total mult-adds (Units.GIGABYTES): 11.86
# =======================================================================================================================================
# Input size (MB): 9.86
# Forward/backward pass size (MB): 4228.93
# Params size (MB): 612.09
# Estimated Total Size (MB): 4850.88
# =======================================================================================================================================
#
# Fusion Phase 2 model summary saved successfully.

# %%
torch.set_grad_enabled(True)
# Out:
# torch.autograd.grad_mode.set_grad_enabled(mode=True)

# %%
# Cell 17 — Phase 3: Optional Backbone Fine-Tuning  [updated for DINOv2]

ckpt  = torch.load(FUSION_CKPT, map_location=DEVICE, weights_only=False)
state = model.state_dict()
state.update(ckpt["fusion_state"])
model.load_state_dict(state)

test_p2 = eval_mm(model, mm_test_loader, criterion)
print(f"Phase 2 test — Acc={test_p2['acc']:.4f}  UAR={test_p2['uar']:.4f}  F1={test_p2['f1']:.4f}")

if test_p2["acc"] < 0.85:
    print("\nPhase 3: Unfreezing top backbone layers for joint fine-tuning...")

    # Unfreeze top 2 WavLM layers  [same as v2]
    for layer in list(model.ser.backbone.encoder.layers)[-2:]:
        for p in layer.parameters(): p.requires_grad = True

    # Unfreeze last 4 DINOv2 ViT blocks + final norm  [v3: was ConvNeXt stages]
    for blk in model.fer.backbone.blocks[-4:]:
        for p in blk.parameters(): p.requires_grad = True
    for p in model.fer.backbone.norm.parameters():
        p.requires_grad = True

    # Unfreeze FER temporal attention (it should already be unfrozen,
    # but re-enable explicitly in case extract_features is torch.no_grad'd)
    for p in model.fer.temporal_attn.parameters(): p.requires_grad = True

    opt3 = AdamW([
        {"params": [p for n, p in model.named_parameters()
                    if p.requires_grad and "ser.backbone" in n],
         "lr": FINETUNE_BACKBONE_LR},
        {"params": [p for n, p in model.named_parameters()
                    if p.requires_grad and "fer.backbone" in n],
         "lr": FINETUNE_BACKBONE_LR},
        {"params": [p for n, p in model.named_parameters()
                    if p.requires_grad and ("fusion" in n or "classifier" in n
                                            or "temporal_attn" in n)],
         "lr": FINETUNE_FUSION_LR},
    ], weight_decay=WEIGHT_DECAY)

    sch3    = CosineAnnealingWarmRestarts(opt3, T_0=5, eta_min=1e-7)
    scaler3 = GradScaler()
    CKPT3   = os.path.join(SAVE_DIR, "best_fusion_finetuned.pt")
    best3   = test_p2["uar"]

    for epoch in range(1, FINETUNE_EPOCHS + 1):
        tr_loss, tr_acc = train_epoch_mm(model, mm_train_loader, opt3, criterion, scaler3)
        val_m           = eval_mm(model, mm_val_loader, criterion)
        sch3.step()
        print(f"P3 Ep {epoch:02d}/{FINETUNE_EPOCHS}  train_acc={tr_acc:.4f}  val_acc={val_m['acc']:.4f}  val_uar={val_m['uar']:.4f}")
        if val_m["uar"] > best3:
            best3 = val_m["uar"]
            torch.save({"model_state": model.state_dict(), "val_uar": best3}, CKPT3)
            print(f"  ✓ Best P3 UAR={best3:.4f}")

    if os.path.exists(CKPT3):
        ckpt3 = torch.load(CKPT3, map_location=DEVICE, weights_only=False)
        model.load_state_dict(ckpt3["model_state"])
        print(f"Phase 3 done. Best UAR={best3:.4f}")
else:
    print(f"Acc={test_p2['acc']:.4f} >= 85% — skipping Phase 3.")
# Out:
# Fusion eval:   0%|          | 0/54 [00:00<?, ?it/s]
# Phase 2 test — Acc=0.8426  UAR=0.8559  F1=0.8481
#
# Phase 3: Unfreezing top backbone layers for joint fine-tuning...
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 01/10  train_acc=0.9653  val_acc=0.9306  val_uar=0.9271
#   ✓ Best P3 UAR=0.9271
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 02/10  train_acc=0.9722  val_acc=0.9028  val_uar=0.8958
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 03/10  train_acc=0.9740  val_acc=0.9167  val_uar=0.9115
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 04/10  train_acc=0.9792  val_acc=0.9167  val_uar=0.9115
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 05/10  train_acc=0.9705  val_acc=0.9167  val_uar=0.9115
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 06/10  train_acc=0.9826  val_acc=0.9306  val_uar=0.9271
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 07/10  train_acc=0.9774  val_acc=0.9167  val_uar=0.9115
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 08/10  train_acc=0.9740  val_acc=0.8750  val_uar=0.8646
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 09/10  train_acc=0.9826  val_acc=0.8750  val_uar=0.8646
# Fusion train:   0%|          | 0/144 [00:00<?, ?it/s]
# Fusion eval:   0%|          | 0/18 [00:00<?, ?it/s]
# P3 Ep 10/10  train_acc=0.9774  val_acc=0.8750  val_uar=0.8646
# Phase 3 done. Best UAR=0.9271

# %%
from torchinfo import summary
import matplotlib.pyplot as plt

model.eval()
torch.set_grad_enabled(False)

summary_p3 = summary(
    model,
    input_size=[
        (1, MAX_SAMPLES),
        (1, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE)
    ],
    device=DEVICE,
    verbose=0,
    col_names=[
        "input_size",
        "output_size",
        "num_params"
    ]
)

# print(summary_p3)

# Convert summary to string
summary_str = str(summary_p3)

# Print in notebook
print(summary_str)

# ===== Save TXT =====
with open("Phase3_Finetuning_Model_Summary.txt", "w") as f:
    f.write(summary_str)

# ===== Save PNG =====
plt.figure(figsize=(15, 20))

plt.text(
    0.01,
    0.99,
    summary_str,
    family='monospace',
    fontsize=7,
    va='top'
)

plt.axis('off')

plt.savefig(
    "Phase3_Finetuning_Model_Summary.png",
    dpi=300,
    bbox_inches='tight'
)

plt.close()

print("\nPhase 3 model summary saved successfully.")
# Out:
# =======================================================================================================================================
# Layer (type:depth-idx)                                       Input Shape               Output Shape              Param #
# =======================================================================================================================================
# MultimodalEmotionModel                                       [1, 56000]                [1, 4]                    --
# ├─SERModel: 1-1                                              --                        --                        198,404
# │    └─WavLMModel: 2-1                                       [1, 56000]                [1, 174, 768]             768
# │    │    └─WavLMFeatureEncoder: 3-1                         [1, 56000]                [1, 512, 174]             (4,200,448)
# │    │    └─WavLMFeatureProjection: 3-2                      [1, 174, 512]             [1, 174, 768]             (395,008)
# │    │    └─WavLMEncoder: 3-3                                [1, 174, 768]             [1, 174, 768]             89,785,712
# │    └─WeightedLayerFusion: 2-2                              [1, 174, 768]             [1, 174, 768]             (12)
# │    └─SpeakerNorm: 2-3                                      [1, 174, 768]             [1, 174, 768]             --
# │    │    └─InstanceNorm1d: 3-4                              [1, 768, 174]             [1, 768, 174]             (1,536)
# │    └─AttentionPooling: 2-4                                 [1, 174, 768]             [1, 768]                  768
# │    │    └─MultiheadAttention: 3-5                          [1, 1, 768]               [1, 1, 768]               (2,362,368)
# │    └─LayerNorm: 2-5                                        [1, 768]                  [1, 768]                  (1,536)
# ├─FERModel: 1-2                                              --                        --                        198,404
# │    └─VisionTransformer: 2-6                                [16, 3, 224, 224]         [16, 768]                 198,144
# │    │    └─PatchEmbed: 3-6                                  [16, 3, 224, 224]         [16, 256, 768]            (452,352)
# │    │    └─Dropout: 3-7                                     [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-8                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Identity: 3-9                                    [16, 257, 768]            [16, 257, 768]            --
# │    │    └─Sequential: 3-10                                 [16, 257, 768]            [16, 257, 768]            85,072,896
# │    │    └─LayerNorm: 3-11                                  [16, 257, 768]            [16, 257, 768]            1,536
# │    │    └─Identity: 3-12                                   [16, 768]                 [16, 768]                 --
# │    │    └─Dropout: 3-13                                    [16, 768]                 [16, 768]                 --
# │    │    └─Identity: 3-14                                   [16, 768]                 [16, 768]                 --
# │    └─TemporalSelfAttention: 2-7                            [1, 16, 768]              [1, 16, 768]              12,288
# │    │    └─TransformerEncoder: 3-15                         [1, 16, 768]              [1, 16, 768]              9,454,080
# │    │    └─LayerNorm: 3-16                                  [1, 16, 768]              [1, 16, 768]              1,536
# │    └─LayerNorm: 2-8                                        [1, 768]                  [1, 768]                  (1,536)
# ├─GatedFusion: 1-3                                           [1, 768]                  [1, 512]                  --
# │    └─Sequential: 2-9                                       [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-17                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-18                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-19                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-10                                      [1, 768]                  [1, 512]                  --
# │    │    └─Linear: 3-20                                     [1, 768]                  [1, 512]                  393,728
# │    │    └─LayerNorm: 3-21                                  [1, 512]                  [1, 512]                  1,024
# │    │    └─GELU: 3-22                                       [1, 512]                  [1, 512]                  --
# │    └─Sequential: 2-11                                      [1, 1024]                 [1, 512]                  --
# │    │    └─Linear: 3-23                                     [1, 1024]                 [1, 512]                  524,800
# │    │    └─Sigmoid: 3-24                                    [1, 512]                  [1, 512]                  --
# │    └─Dropout: 2-12                                         [1, 512]                  [1, 512]                  --
# ├─Sequential: 1-4                                            [1, 512]                  [1, 4]                    --
# │    └─Linear: 2-13                                          [1, 512]                  [1, 256]                  131,328
# │    └─LayerNorm: 2-14                                       [1, 256]                  [1, 256]                  512
# │    └─GELU: 2-15                                            [1, 256]                  [1, 256]                  --
# │    └─Dropout: 2-16                                         [1, 256]                  [1, 256]                  --
# │    └─Linear: 2-17                                          [1, 256]                  [1, 4]                    1,028
# =======================================================================================================================================
# Total params: 193,786,504
# Trainable params: 53,451,052
# Non-trainable params: 140,335,452
# Total mult-adds (Units.GIGABYTES): 11.86
# =======================================================================================================================================
# Input size (MB): 9.86
# Forward/backward pass size (MB): 4228.93
# Params size (MB): 612.09
# Estimated Total Size (MB): 4850.88
# =======================================================================================================================================
#
# Phase 3 model summary saved successfully.

# %%
# Cell 18 — Training Curves  [UNCHANGED from v2]

epochs_ran = len(history["train_acc"])
x = range(1, epochs_ran + 1)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(x, history["train_loss"], label="Train", color="#e74c3c")
axes[0].plot(x, history["val_loss"],   label="Val",   color="#3498db")
axes[0].set_title("Loss"); axes[0].set_xlabel("Epoch")
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(x, history["train_acc"], label="Train", color="#e74c3c")
axes[1].plot(x, history["val_acc"],   label="Val",   color="#3498db")
axes[1].axhline(0.85, color="green", ls="--", alpha=0.5, label="85% target")
axes[1].set_title("Accuracy"); axes[1].set_xlabel("Epoch")
axes[1].legend(); axes[1].grid(alpha=0.3)

axes[2].plot(x, history["val_uar"], label="UAR", color="#9b59b6")
axes[2].plot(x, history["val_f1"],  label="F1",  color="#2ecc71")
axes[2].set_title("Val UAR & F1"); axes[2].set_xlabel("Epoch")
axes[2].legend(); axes[2].grid(alpha=0.3)

plt.suptitle("Phase 2 — Gated Fusion v3 Training Curves", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "training_curves.png"), dpi=150)
plt.show()

# %%
# Cell 19 — Final Evaluation & Confusion Matrix  [UNCHANGED from v2]

test_m = eval_mm(model, mm_test_loader, criterion)

print(f"\n{'='*60}")
print(f"FINAL TEST RESULTS")
print(f"  Accuracy : {test_m['acc']:.4f} ({test_m['acc']*100:.2f}%)")
print(f"  UAR      : {test_m['uar']:.4f}")
print(f"  Macro-F1 : {test_m['f1']:.4f}")
print(f"{'='*60}")
print(classification_report(test_m["labels"], test_m["preds"],
                             target_names=EMOTION_LABELS, digits=4))

print("Unimodal baselines (pre-trained backbones):")
print(f"  SER (audio-only) — Acc={test_ser['acc']:.4f}  UAR={test_ser['uar']:.4f}")
print(f"  FER (visual-only)— Acc={test_fer['acc']:.4f}  UAR={test_fer['uar']:.4f}")
print(f"  Gated Fusion v3  — Acc={test_m['acc']:.4f}    UAR={test_m['uar']:.4f}")

fig, ax = plt.subplots(figsize=(7, 6))
cm     = confusion_matrix(test_m["labels"], test_m["preds"])
cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100

sns.heatmap(cm_pct, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=EMOTION_LABELS, yticklabels=EMOTION_LABELS, ax=ax)
ax.set_title(f"Gated Fusion v3 — Acc={test_m['acc']:.2%}")
ax.set_ylabel("True"); ax.set_xlabel("Predicted")

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "confusion_matrix.png"), dpi=150)
plt.show()
# Out:
# Fusion eval:   0%|          | 0/54 [00:00<?, ?it/s]
# ============================================================
# FINAL TEST RESULTS
#   Accuracy : 0.8611 (86.11%)
#   UAR      : 0.8663
#   Macro-F1 : 0.8625
# ============================================================
#               precision    recall  f1-score   support
#
#        angry     0.8519    0.9583    0.9020        48
#        happy     0.9583    0.9583    0.9583        48
#      neutral     0.8551    0.8194    0.8369        72
#          sad     0.7778    0.7292    0.7527        48
#
#     accuracy                         0.8611       216
#    macro avg     0.8608    0.8663    0.8625       216
# weighted avg     0.8601    0.8611    0.8596       216
#
# Unimodal baselines (pre-trained backbones):
#   SER (audio-only) — Acc=0.7593  UAR=0.7587
#   FER (visual-only)— Acc=0.7130  UAR=0.7413
#   Gated Fusion v3  — Acc=0.8611    UAR=0.8663

# %%
# Cell 20 — Gate Analysis (which modality wins per emotion?)  [UNCHANGED from v2]

@torch.no_grad()
def get_gates(model, loader):
    model.eval()
    gates, lbls = [], []
    for wav, clip, labels in tqdm(loader, desc="Gate analysis", leave=False):
        _, g = model(wav.to(DEVICE), clip.to(DEVICE), return_gate=True)
        gates.append(g.cpu()); lbls.extend(labels.tolist())
    return torch.cat(gates), np.array(lbls)

gates, glabels = get_gates(model, mm_test_loader)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
colors = ["#e74c3c", "#f39c12", "#3498db", "#2ecc71"]
means  = [gates[glabels == i].mean().item() for i in range(NUM_CLASSES)]

bars = axes[0].bar(EMOTION_LABELS, means, color=colors, edgecolor="white")
axes[0].axhline(0.5, color="gray", ls="--", alpha=0.5)
axes[0].set_ylim(0, 1); axes[0].set_ylabel("Mean Gate Value")
axes[0].set_title("Modality Preference (↑=Audio, ↓=Visual)")
for b, v in zip(bars, means):
    axes[0].text(b.get_x() + b.get_width() / 2, v + 0.02, f"{v:.3f}", ha="center")

for i, em in enumerate(EMOTION_LABELS):
    g_avg = gates[glabels == i].mean(dim=-1).numpy()
    axes[1].hist(g_avg, bins=20, alpha=0.5, label=em, color=colors[i])
axes[1].axvline(0.5, color="gray", ls="--"); axes[1].legend()
axes[1].set_title("Gate Distribution per Emotion")

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "gate_analysis.png"), dpi=150)
plt.show()

print("\nGate value breakdown:")
for i, em in enumerate(EMOTION_LABELS):
    g    = gates[glabels == i].mean(dim=-1)
    bias = "↑ Audio" if g.mean() > 0.55 else "↓ Visual" if g.mean() < 0.45 else "≈ Balanced"
    print(f"  {em:<10}: mean={g.mean():.4f}  std={g.std():.4f}  {bias}")

print("\nInterpretation (v3 expectation):")
print("  With DINOv2 + Temporal Attention, gate values for visual-rich emotions")
print("  (happy, sad) should shift toward ↓ Visual vs v2 where audio dominated.")
# Out:
# Gate analysis:   0%|          | 0/54 [00:00<?, ?it/s]
# Gate value breakdown:
#   angry     : mean=0.5120  std=0.0174  ≈ Balanced
#   happy     : mean=0.4268  std=0.0261  ↓ Visual
#   neutral   : mean=0.4826  std=0.0236  ≈ Balanced
#   sad       : mean=0.5308  std=0.0280  ≈ Balanced
#
# Interpretation (v3 expectation):
#   With DINOv2 + Temporal Attention, gate values for visual-rich emotions
#   (happy, sad) should shift toward ↓ Visual vs v2 where audio dominated.

# %%
# Cell 21 — Save Final Package  [updated for v3 config]
import datetime

final_path = os.path.join(SAVE_DIR, "multimodal_final_v3.pt")
torch.save({
    "model_state": model.state_dict(),
    "config": {
        "version"       : "v3",
        "fusion_dim"    : FUSION_DIM,
        "n_classes"     : NUM_CLASSES,
        "dropout"       : DROPOUT,
        "emotion_labels": EMOTION_LABELS,
        "audio_dim"     : 768,
        "visual_dim"    : VISUAL_DIM,    # 768 (DINOv2 ViT-B)
        "num_frames"    : NUM_FRAMES,    # 16
        "img_size"      : IMG_SIZE,      # 224
        "fer_backbone"  : "vit_base_patch14_dinov2.lvd142m",
        "ser_backbone"  : "microsoft/wavlm-base-plus",
    },
    "results": {
        "ser_test_acc"   : float(test_ser["acc"]),
        "fer_test_acc"   : float(test_fer["acc"]),
        "fusion_test_acc": float(test_m["acc"]),
        "fusion_test_uar": float(test_m["uar"]),
        "fusion_test_f1" : float(test_m["f1"]),
    },
    "ser_ckpt" : best_ser_ckpt,
    "fer_ckpt" : best_fer_ckpt,
    "timestamp": datetime.datetime.now().isoformat(),
}, final_path)

print(f"Saved to: {final_path}")
print(f"\n{'='*60}")
print(f"  SER   (audio-only) : {test_ser['acc']*100:.2f}%")
print(f"  FER   (visual-only): {test_fer['acc']*100:.2f}%")
print(f"  Gated Fusion v3    : {test_m['acc']*100:.2f}%")
print(f"{'='*60}")
print(f"\n✅ All done! Checkpoint: {final_path}")
# Out:
# Saved to: /kaggle/working/model_file/multimodal_final_v3.pt
#
# ============================================================
#   SER   (audio-only) : 75.93%
#   FER   (visual-only): 71.30%
#   Gated Fusion v3    : 86.11%
# ============================================================
#
# ✅ All done! Checkpoint: /kaggle/working/model_file/multimodal_final_v3.pt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import torch

def plot_emotion_cm(model, loader, device, classes, title="Confusion Matrix", is_multimodal=False):
    model.eval()
    all_preds, all_labels = [], []
    
    with torch.no_grad():
        for batch in loader:
            if is_multimodal:
                wav, clip, labels = batch
                wav, clip = wav.to(device), clip.to(device)
                logits = model(wav, clip)
            else:
                inputs, labels = batch
                inputs = inputs.to(device)
                logits = model(inputs)
            
            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())
    
    # Generate Matrix
    cm = confusion_matrix(all_labels, all_preds)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] # Normalization

    plt.figure(figsize=(7, 5))
    sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='RdPu', 
                xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('Actual Emotion')
    plt.xlabel('Predicted Emotion')
    _ = ['ser_confusion_matrix', 'fer_confusion_matrix', 'multimodal_confusion_matrix']
    for i in _:
        filename=i
        # SAVE THE FILE
        plt.savefig(filename, dpi=1200, bbox_inches='tight')
        print(f"Saved: {filename}")
    plt.show()

# 1. SER Matrix
plot_emotion_cm(ser_model, ser_test_loader, DEVICE, EMOTION_LABELS, "SER Confusion Matrix (WavLM)")

# 2. FER Matrix
plot_emotion_cm(fer_model, fer_test_loader, DEVICE, EMOTION_LABELS, "FER Confusion Matrix (DINOv2)")

# 3. Fusion Matrix (The final multimodal system)
plot_emotion_cm(model, mm_test_loader, DEVICE, EMOTION_LABELS, "Gated Fusion Confusion Matrix", is_multimodal=True)
# Out:
# Saved: ser_confusion_matrix
# Saved: fer_confusion_matrix
# Saved: multimodal_confusion_matrix
# Saved: ser_confusion_matrix
# Saved: fer_confusion_matrix
# Saved: multimodal_confusion_matrix
# Saved: ser_confusion_matrix
# Saved: fer_confusion_matrix
# Saved: multimodal_confusion_matrix
